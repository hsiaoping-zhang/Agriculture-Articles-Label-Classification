# %% [markdown]
# # 資料前處理
#
# 將主辦方提供的資料進行處理(斷詞/分類)，以利後續處理分析

# %%
currentFolder = "train"

# %% [markdown]
# ### 贅字錯誤排除
#
# 由於主辦方給的字典在第一次轉換後還是會產生 `\x7f` 的字形造成無法順利判讀，因此先針對 pest 和 chem 類別進行再處理。
# 並將同一種含意但不同詞的表示方法建立一個 dictionary 提供查找

# %%
def replace_abnormal_character(file, name_list, name_dict):
    file = open(file, "r", encoding='utf-8-sig')
    # only get content with .readlines() method, the program can read the abnormal character
    rows = file.readlines()  
    file.close()
    
    for i in range(len(rows)):
        row = rows[i].strip("\n").strip(",").replace("\x7f", "").split(",")
        name_list.append(row[0])
        for item in row:
            name_dict[item] = i  # the same meaning words with the same index nuber

# %%
# 作物字典

crop_list = []
crop_dict = {}

replace_abnormal_character("train/KeyWords/02crop_list.csv", crop_list, crop_dict)
crop_list[:10]
# Out:
# ['文旦柚', '水稻', '青蔥', '龍鬚菜', '韭菜', '甘藍', '西瓜', '芋頭', '香蕉', '甘藷']

# %%
## 疫病及蟲害字典

pest_dict = {}
pest_list = []

replace_abnormal_character("train/Keywords/02pest_list.csv", pest_list, pest_dict)
print(pest_list[:10])
# Out:
# ['斜紋夜蛾', '甜菜夜蛾', '黑點病', '軟腐病', '疫病', '炭疽病', '潰瘍病', '白絹病', '黑腐病', '紫斑病']

# %%
pest_dict["柑桔窄胸天牛"]
# Out:
# 104

# %%
## 化學字典

chem_dict = {}
chem_list = []

replace_abnormal_character("train/Keywords/02chem_list.csv", chem_list, chem_dict)
print(chem_list[:10])
# Out:
# ['貝芬硫醌', '腈硫醌', '鋅錳乃浦', '性費洛蒙', '蘇力菌', '比多農', '夏油', '亞磷酸', '乳化葵花油', '窄域油']

# %% [markdown]
# ### 文章完全斷詞空格分開

# %%
import re
import jieba
import jieba.analyse
import jieba.posseg as pseg

# %%
# 載入使用者定義字典：在斷詞的時候能夠區別關鍵字並給予對應新增類別詞性 (ex: crop, chem, pest...)

jieba.set_dictionary('dict.txt.big')
jieba.load_userdict('chem_dict.txt')
jieba.load_userdict('crop_dict.txt')
jieba.load_userdict('pest_dict.txt')

print("OK")
# Out:
# Building prefix dict from /Users/hsiaoping.zhang/Desktop/AIDEA/dict.txt.big ...
# Loading model from cache /var/folders/rd/0nr5tzsn2z17vy9fjcj5rlsc0000gn/T/jieba.u5524b13f3f9f1a3fca714e7a1c7506b3.cache
# Loading model cost 0.532 seconds.
# Prefix dict has been built successfully.
# OK

# %%
# stop words

stopwords_file = open("stop_words.txt", "r")
stopwords = stopwords_file.readlines()
stopwords = [item.strip("\n") for item in stopwords]
print("stop words OK.")
# Out:
# stop words OK.

# %% [markdown]
# ### 文章斷詞
#
# 將文章使用斷詞將字詞以空格分開，並去除掉數字與英文的部份(這裡視為沒有意義的詞，因為出現不多，且大多指示藥劑濃度)
# 並在斷詞時因為有載入先前使用者定義字典幫助斷詞並分類詞性

# %%
from os import listdir
from os.path import isfile, isdir, join

# %%
def article_segment(full_file_path, fileNum):
    
    file = open(full_file_path, "r", encoding='utf-8-sig', errors='ignore')
    sentances = file.readlines()
    file.close()

    text = ""
    for item in sentances:
        replace = re.sub(r'[0-9]+|[%]|[-]|[a-z]','', item.replace("\x7f", ""))
        text += replace
        
    result = ""
    words = pseg.cut(text)
    except_speech = ["m", "p", "d", "c", "eng"]
    part_speech = ["v", "n", "t", "event", "crop", "pest", "chem", "city"]
    for word, flag in words:
        # only extract a word with length >= 2 and part of speech with v, n, t, and key words!!
        if(word not in stopwords and len(word) > 1 and flag not in except_speech):
            result += (word + " ")

    # record to another file
    file = open(f"{currentFolder}/ArticleSegment/{fileNum}.txt", "w")  # 放入 /ArticleSegment 資料夾
    file.write(f"{result}\n")
    file.close()

# %%
currentFolder = "private"

# %%
# all file in directory
mypath = f"{currentFolder}/data{currentFolder.capitalize()}Complete"
files = listdir(mypath)

count = 0
print("...")

for f in files:
    fullpath = join(mypath, f)
    if isfile(fullpath):
        fileNum = f.split(".")[0]
        article_segment(fullpath, fileNum)
    count += 1
    if(count % 100 == 0):
        print(count, end=" | ")

print("\nfinish")
# Out:
# 100
# 200
# 300
# 400
# 500
# finish

# %% [markdown]
# ### 提取關鍵詞
#
# 只留下關鍵字作為第一層判斷依據，crop pest chem 三類並另存到 csv 檔案當中
# 並在提取關鍵字的過程當中，將一些同義異字的詞轉換為同一個代表詞，以利於後續判斷

# %%
def extract_keywords_to_file(full_file_path, fileNum):
    file = open(full_file_path, "r", encoding='utf-8-sig', errors='ignore')
    sentances = file.readlines()
    file.close()
    
    text = ""
    for item in sentances:
        replace = re.sub(r'[0-9]+|[%]|[-]','', item.replace("\x7f", ""))
        text += replace
    text = text.replace("寧", "寧")
    
    # 斷詞取詞性
    words = pseg.cut(text)
    keywords = [[] for i in range(4)]
    key_index_list = ["crop", "pest", "chem", "city"]
    
    
    # extract keywords in the given dictionaries
    for word, flag in words:
        if flag in key_index_list:
            index = key_index_list.index(flag)
            if(flag == "city"):
                word = word.replace("市", "").replace("縣", "").replace("台", "臺")
                
            if(word not in keywords[index]):
                if(flag =="crop"):
                    i = crop_dict[word]
                    word = crop_list[i]
            
                elif(flag == "pest"):
                    i = pest_dict[word]
                    word = pest_list[i]
                    
                elif(flag == "chem"):
                    i = chem_dict[word]
                    word = chem_list[i]
                    
                if(word in keywords[index]):  # 再次檢查是否重複
                    continue
                    
                keywords[index].append(word)
            
    # write file
    print(f"file: {fileNum}")
    file = open(f"{currentFolder}/data/" + str(fileNum) + ".csv", "w")  # 放入 /data 資料夾
    print(keywords)
    
    for key_list in keywords:
        row = ""
        for key in key_list:
            row += (key + ",")
        row = row.strip(",") + "\n"
        file.write(row)

    file.close()
    print("- - -")
    
print("updated")
# Out:
# updated

# %%
# all file in directory
mypath = f"{currentFolder}/data{currentFolder.capitalize()}Complete"
files = listdir(mypath)


for f in files:
    fullpath = join(mypath, f)
    if isfile(fullpath):
        fileNum = f.split(".")[0]
        extract_keywords_to_file(fullpath, fileNum)
        
print("finish")
# Out:
# file: 1047
# [['水稻', '雜草'], ['葉稻熱病', '水稻水象鼻蟲'], ['甲基多保淨', '嘉賜三賽唑', '護粒三賽唑', '保米熱斯', '三賽唑', '加普胺', '培丹', '免扶克', '加保扶', '丁基加保扶'], ['苗栗']]
# - - -
# file: 1090
# [['水稻'], ['稻熱病', '細菌性條斑病', '葉稻熱病', '白葉枯病'], ['微生物製劑', '亞磷酸'], ['花蓮']]
# - - -
# file: 1279
# [['香蕉', '雜草'], ['花薊馬', '水銹斑'], ['第滅寧', '陶斯松', '福瑞松'], []]
# - - -
# file: 1286
# [['香蕉'], ['象鼻蟲', '假莖象鼻蟲', '球莖象鼻蟲'], ['凡殺護矽得', '加保扶'], []]
# - - -
# file: 15
# [['水稻'], ['瘤野螟', '飛蝨類', '白背飛蝨', '褐飛蝨'], ['蘇力菌', '苦楝油', '菸草水'], ['花蓮']]
# - - -
# file: 855
# [['芋頭', '雜草'], ['斜紋夜蛾'], ['美文松', '培丹', '阿巴汀', '蘇力菌', '性費洛蒙'], ['花蓮', '宜蘭']]
# - - -
# file: 100
# [['水稻'], ['葉稻熱病', '稻熱病'], ['甲基多保淨', '芬諾尼', '嘉賜黴素', '克熱賜圃', '嘉賜三賽唑', '富米熱斯', '保米熱斯', '護粒三賽唑', '丙基喜樂松', '亞賜圃'], ['桃園']]
# - - -
# file: 882
# [['鳳梨'], ['葉螨'], ['芬普寧', '克芬螨', '密滅汀'], ['花蓮']]
# - - -
# file: 316
# [['番荔枝', '鳳梨釋迦', '雜草'], ['葉螨', '荔枝葉螨', '神澤氏葉螨', '二點葉螨'], ['芬普螨', '亞醌螨', '密滅汀', '芬普寧', '畢達本', '畢汰芬', '得芬瑞', '賜派芬', '賜滅芬'], ['臺東']]
# - - -
# file: 302
# [['水稻'], ['稻熱病', '穗稻熱病'], ['護粒松', '喜樂克拉', '三賽唑'], ['臺東']]
# - - -
# file: 317
# [['水稻', '雜草'], ['白背飛蝨', '飛蝨類'], ['苦楝油', '礦物油'], ['臺東']]
# - - -
# file: 883
# [['高接梨', '水稻', '蔬菜'], [], [], ['花蓮']]
# - - -
# file: 101
# [['水稻'], ['二化螟', '螟蟲'], ['培丹', '撲滅松'], ['桃園']]
# - - -
# file: 115
# [['蓮霧', '檬果'], ['小黃薊馬', '薊馬'], ['亞滅培', '丁基加保扶', '亞滅寧', '達特南', '賽洛寧', '賜諾特', '滅賜克'], ['高雄', '屏東']]
# - - -
# file: 840
# [['水稻'], ['負泥蟲'], ['益滅松', '撲滅松', '益滅蝨', '加保扶', '納乃得', '丁基加保扶'], ['花蓮']]
# - - -
# file: 1293
# [['香蕉'], [], ['鋅錳乃浦', '普克利'], []]
# - - -
# file: 934
# [['水稻'], ['紋枯病'], ['菲克利', '賽氟滅', '四克利', '賓克隆', '福多寧', '福拉比'], ['桃園']]
# - - -
# file: 920
# [['水稻', '雜草'], ['水稻水象鼻蟲'], ['加保扶', '益達胺', '培丹'], ['桃園']]
# - - -
# file: 539
# [['水稻'], ['二化螟'], ['培丹', '芬普尼', '撲滅松'], ['臺中', '彰化']]
# - - -
# file: 1046
# [['檬果'], ['小黃薊馬', '薊馬'], ['芬普尼', '克凡派'], ['高雄', '屏東']]
# - - -
# file: 1044
# [['芒果'], ['小黃薊馬'], ['丁基加保扶', '芬普尼'], ['臺南']]
# - - -
# file: 1078
# [['水稻'], ['葉稻熱病', '稻熱病'], [], ['雲林', '臺南']]
# - - -
# file: 513
# [['水稻'], ['稻熱病', '水稻水象鼻蟲', '葉稻熱病', '象鼻蟲'], [], ['苗栗']]
# - - -
# file: 275
# [['番荔枝', '香蕉', '荖葉', '果樹', '水稻', '雜草', '荖花'], [], [], ['臺東']]
# - - -
# file: 507
# [['草莓'], ['炭疽病'], ['腐絕快得寧', '待克利', '百克敏', '三氟派瑞'], ['苗栗']]
# - - -
# file: 1246
# [['香蕉'], ['黑星病'], ['鋅錳乃浦'], []]
# - - -
# file: 922
# [['水稻', '雜草'], ['紋枯病'], ['菲克利', '賽氟滅', '四克利', '賓克隆', '福多寧', '福拉比'], ['桃園', '臺北']]
# - - -
# file: 1291
# [['香蕉', '雜草'], ['花薊馬', '水銹斑'], ['第滅寧', '陶斯松', '福瑞松'], []]
# - - -
# file: 842
# [['水稻', '玉米', '甘庶', '茭白荀', '小麥', '牧草', '雜草', '柑桔', '文旦'], ['水稻水象鼻蟲', '小黃薊馬', '蚜蟲', '介殼蟲', '薊馬', '花薊馬', '南黃薊馬'], ['免扶克', '培丹', '加保扶', '丁基加保扶', '賽洛寧', '畢芬寧', '納乃得'], ['花蓮', '桃園', '新竹', '苗栗', '南投']]
# - - -
# file: 16
# [['荔枝', '龍眼', '無患子科', '台灣欒樹', '文旦', '蓮霧'], ['荔枝椿象'], ['陶斯松', '賽洛寧'], ['宜蘭', '花蓮']]
# - - -
# file: 895
# [['芒果'], ['小黃薊馬', '薊馬'], ['克凡派', '可尼丁', '亞滅培', '第滅達胺'], ['屏東']]
# - - -
# file: 467
# [['水稻'], ['葉稻熱病', '白葉枯病'], [], []]
# - - -
# file: 328
# [['檬果'], ['炭疽病'], ['扶吉胺', '克熱淨', '免得爛', '三氟敏', '賽普護汰寧', '克收欣', '亞托敏', '貝芬撲克拉', '待克利', '腐絕快得寧', '腈硫醌', '甲基鋅乃浦', '撲克拉錳', '甲基多保淨', '錳乃浦', '鋅錳乃浦', '撲克拉'], ['臺南']]
# - - -
# file: 314
# [['水稻'], ['稻熱病', '負泥蟲'], ['撲殺熱', '護粒松', '喜樂克拉', '三賽唑', '培丹'], ['臺東']]
# - - -
# file: 466
# [['水稻'], ['稻熱病', '葉稻熱病'], ['撲殺熱', '嘉賜三賽唑', '護粒三賽唑', '保米熱斯', '三賽唑', '加普胺'], ['苗栗']]
# - - -
# file: 658
# [['果樹', '芒果', '柑橘', '酪梨', '楊桃', '番石榴', '木瓜', '茄科', '茄子', '甜椒', '辣椒', '番茄', '胡麻', '西瓜', '花胡瓜', '九層塔', '萵苣', '豆科', '蔬菜', '馬鈴薯', '棗子', '咖啡', '葡萄', '桑', '茶', '非洲菊', '薰衣草', '柑桔', '荔枝', '蓮霧', '龍眼'], ['腫葉病', '薊馬', '節螨'], ['礦物油', '芬普螨', '新殺福化利', '汰芬隆', '畢達本', '加福松', '阿巴汀', '克芬螨', '丁基加保扶', '加保扶', '可濕性硫磺'], ['臺南']]
# - - -
# file: 17
# [['蔬菜'], ['斜紋夜蛾', '甜菜夜蛾'], ['性費洛蒙', '蘇力菌', '微生物製劑'], ['宜蘭', '花蓮']]
# - - -
# file: 843
# [['草莓'], [], [], ['花蓮']]
# - - -
# file: 710
# [['水稻'], ['穗稻熱病', '稻熱病', '葉稻熱病'], ['三賽唑', '保米熱斯', '嘉賜三賽唑', '加普胺', '克熱淨'], ['臺南']]
# - - -
# file: 260
# [['青蔥', '蔥科'], ['黑腐病', '紫斑病', '黑斑病', '炭疽病'], ['三氟得克利', '依普同', '白列克敏'], ['臺中']]
# - - -
# file: 512
# [['龍眼', '荔枝'], ['荔枝椿象'], [], ['苗栗']]
# - - -
# file: 274
# [['果樹', '番荔枝', '釋迦', '文旦柚', '桶柑', '茂谷柑', '臍橙', '晚崙西亞', '香蕉', '水稻', '雜草', '樹豆', '洛神葵', '荖花', '荖葉'], ['果疫病', '果腐病', '潰瘍病', '疫病', '細菌性角斑病'], ['銅滅達樂', '福賽得', '枯草桿菌', '賽普護汰寧', '波爾多', '氧化亞銅', '嘉賜銅'], ['臺東']]
# - - -
# file: 1079
# [[], ['瓜實蠅', '東方果實蠅', '斜紋夜蛾', '果實蠅', '夜蛾類'], ['含毒甲基丁香油', '克蠅', '克蠅香', '性費洛蒙', '蘇力菌'], ['花蓮']]
# - - -
# file: 1045
# [['蔬菜', '番茄', '葫蘆科', '胡瓜', '絲瓜', '洋香瓜', '十字花科', '菠菜', '萵苣', '青蔥', '葉菜類', '瓜類', '菊科', '蔥科'], ['露菌病', '晚疫病'], ['亞托敏', '達滅芬', '鋅錳座賽胺', '達滅克敏'], ['臺南']]
# - - -
# file: 1069
# [[], ['稻熱病'], [], ['高雄']]
# - - -
# file: 1055
# [['水稻'], ['稻熱病', '葉稻熱病'], ['加普胺', '嘉賜三賽唑', '富米熱斯'], ['高雄', '屏東', '臺南']]
# - - -
# file: 258
# [['水稻'], ['飛蝨類', '褐飛蝨', '白背飛蝨'], ['氟尼胺', '賽速安', '可尼丁', '派滅淨', '達特南'], ['臺中', '彰化', '南投']]
# - - -
# file: 502
# [['水稻', '雜草'], ['螟蟲', '象鼻蟲', '水稻水象鼻蟲', '螟蛾', '二化螟', '三化螟'], ['培丹', '芬普尼', '撲滅松', '賽達松', '加保扶', '芬殺松', '益滅松', '免扶克', '丁基加保扶'], ['苗栗']]
# - - -
# file: 1096
# [['水稻'], ['葉稻熱病', '稻熱病'], ['撲殺熱', '亞賜圃', '嘉賜三賽唑', '加普胺', '護粒松', '微生物製劑', '亞磷酸'], ['花蓮']]
# - - -
# file: 1257
# [['蕉株', '雜草'], ['花薊馬'], ['賽洛寧', '陶斯松'], ['雲林']]
# - - -
# file: 1294
# [['蕉株', '雜草'], ['花薊馬', '水銹斑'], ['第滅寧', '陶斯松', '福瑞松'], []]
# - - -
# file: 884
# [['水稻', '蔬菜'], [], [], ['花蓮', '宜蘭']]
# - - -
# file: 890
# [['果樹', '柑桔', '番石榴', '蓮霧', '楊桃', '釋迦', '甜蜜桃'], ['果實蠅', '東方果實蠅'], ['含毒甲基丁香油', '芬化利', '芬殺松', '賽福寧', '蛋白質水解物', '馬拉松'], ['花蓮', '宜蘭']]
# - - -
# file: 106
# [['水稻'], ['稻熱病', '葉稻熱病'], ['三賽唑'], ['高雄']]
# - - -
# file: 674
# [['檬果', '果樹'], ['炭疽病', '白粉病'], ['貝芬四克利', '滅特座', '免得爛', '三氟敏', '賽普護汰寧', '克收欣', '亞托敏', '貝芬撲克拉', '待克利', '腐絕快得寧', '鋅錳邁克尼', '甲基鋅乃浦', '嘉賜貝芬', '撲克拉錳', '錳乃浦', '貝芬錳', '鋅錳乃浦', '撲克拉', '三泰隆', '無水硫酸銅', '四克利', '賽普待克利', '溴克座', '貝芬依滅列', '菲克利腐絕', '平克座', '普克利', '依瑞莫', '布瑞莫', '芬瑞莫', '三泰芬'], ['臺南']]
# - - -
# file: 1109
# [['水稻'], ['葉稻熱病', '稻熱病'], ['撲殺熱', '三賽唑', '嘉賜三賽唑', '加普胺', '護粒松', '矽酸爐渣'], ['南投', '彰化']]
# - - -
# file: 338
# [['柑橘', '果樹', '麻豆文旦', '白柚', '西施柚', '椪柑', '柳橙', '茂谷柑', '明尼吉柚', '葡萄柚'], [], ['畢達本', '阿巴汀', '汰芬隆', '福隆納乃得', '芬佈賜'], ['臺南']]
# - - -
# file: 1134
# [['芒果', '蓮霧', '茄果類', '瓜菜類', '瓜類', '番石榴', '瓜果類', '木瓜', '豆菜類', '果樹', '荔枝', '龍眼', '番茄'], ['粉蝨類', '葉蟬', '瓜實蠅', '果實蠅', '蝶蛾類', '椿象類', '煤煙病'], ['蘇力菌', '礦物油', '印楝素', '可濕性硫磺'], ['高雄']]
# - - -
# file: 1108
# [['果樹', '荔枝', '白柚', '龍眼', '楊桃', '蓮霧', '番石榴'], ['黑角舞蛾', '蝶蛾類'], ['賽洛寧', '第滅寧', '芬化利'], ['彰化', '南投']]
# - - -
# file: 1322
# [['蕉農'], ['象鼻蟲', '假莖象鼻蟲', '球莖象鼻蟲'], ['凡殺護矽得', '加保扶'], []]
# - - -
# file: 1281
# [['香蕉'], ['黑星病'], ['鋅錳乃浦', '普克利', '凡殺護矽得', '亞托敏', '甲基多保淨'], []]
# - - -
# file: 715
# [['柑橘', '果樹', '椪柑', '柳橙', '茂谷柑', '明尼吉柚', '葡萄柚'], [], ['畢達本', '克芬螨', '阿巴汀', '汰芬隆', '福隆納乃得', '芬普螨', '新殺螨', '芬佈賜'], ['臺南']]
# - - -
# file: 729
# [['水稻'], ['葉稻熱病', '稻熱病', '二化螟'], ['撲殺熱', '三賽唑', '護粒松', '喜樂克拉', '亞賜圃', '加普胺', '嘉賜三賽唑', '培丹', '芬普尼', '撲滅松', '陶斯松'], ['臺南']]
# - - -
# file: 1242
# [['香蕉', '豆科', '茄科', '雜草'], ['嵌紋病', '萎縮病', '蚜蟲', '棉蚜', '胡瓜嵌紋病毒'], ['加保扶'], []]
# - - -
# file: 932
# [['聖誕紅', '雜草'], ['銀葉粉蝨', '煤煙病'], ['依殺螨', '阿巴汀', '畢芬寧', '畢達本', '亞滅培', '布芬淨'], ['桃園']]
# - - -
# file: 271
# [['水稻', '胡麻'], ['白葉枯病', '胡麻葉枯病'], ['嘉賜克枯爛', '克枯三賽唑', '鏈四環黴素', '克枯爛', '撲殺熱', '普克利', '鋅錳乃浦', '錳乃浦'], ['臺東', '高雄']]
# - - -
# file: 517
# [[], ['斜紋夜蛾'], ['蘇力菌', '美文松', '賽洛寧', '百滅寧', '畢芬寧', '加保利', '陶斯松', '加保扶', '納乃得', '性費洛蒙'], ['嘉義']]
# - - -
# file: 1083
# [['蕉農'], ['黑星病', '葉斑病'], ['待克利', '亞托敏'], []]
# - - -
# file: 259
# [['荔枝', '龍眼', '欒樹'], ['荔枝椿象'], ['賽洛寧', '亞滅培'], ['臺中', '彰化']]
# - - -
# file: 1042
# [['蔥', '蔥科', '蔬菜'], ['露菌病'], ['亞托敏', '錳乃浦'], ['臺中', '彰化']]
# - - -
# file: 515
# [['水稻', '雜草'], ['瘤野螟'], ['性費洛蒙', '芬殺松', '賽速洛寧', '矽護芬', '賽洛寧', '布芬第滅寧', '培丹'], ['苗栗']]
# - - -
# file: 1240
# [['蕉農'], ['黑星病'], ['鋅錳乃浦'], []]
# - - -
# file: 1297
# [['香蕉', '雜草'], ['花薊馬', '水銹斑'], ['第滅寧', '陶斯松', '福瑞松'], []]
# - - -
# file: 703
# [['芒果', '果樹'], ['炭疽病', '白粉病'], ['貝芬四克利', '滅特座', '免得爛', '三氟敏', '賽普護汰寧', '克收欣', '亞托敏', '貝芬撲克拉', '待克利', '腐絕快得寧', '鋅錳邁克尼', '甲基鋅乃浦', '嘉賜貝芬', '撲克拉錳', '錳乃浦', '貝芬錳', '鋅錳乃浦', '百克敏', '得克利', '撲克拉', '三泰隆', '無水硫酸銅', '四克利', '賽普待克利', '溴克座', '貝芬依滅列', '菲克利腐絕', '平克座', '普克利', '依瑞莫', '布瑞莫', '芬瑞莫', '三泰芬'], ['臺南']]
# - - -
# file: 1283
# [['香蕉'], [], [], []]
# - - -
# file: 1308
# [['香蕉'], ['黑星病', '葉斑病'], ['鋅錳乃浦', '普克利', '凡殺護矽得', '亞托敏'], []]
# - - -
# file: 139
# [['木瓜', '果樹'], ['疫病', '炭疽病', '黑腐病', '褐斑病'], ['亞磷酸', '甲基鋅乃浦', '免得爛', '得克利', '賽普護汰寧', '嘉賜銅'], ['高雄']]
# - - -
# file: 677
# [['水稻'], ['葉稻熱病', '稻熱病', '二化螟'], ['撲殺熱', '三賽唑', '護粒松', '保米賜圃'], []]
# - - -
# file: 1122
# [['果樹', '甜柿', '荔枝', '龍眼', '楊桃', '蓮霧', '番石榴', '柑橘', '橄欖', '枇杷'], ['黑角舞蛾'], ['賽洛寧', '第滅寧'], ['臺中', '彰化', '南投']]
# - - -
# file: 1136
# [['水稻'], ['穗稻熱病', '稻熱病'], ['護粒三賽唑', '亞賜圃', '嘉賜黴素'], ['高雄']]
# - - -
# file: 448
# [[], ['銹病'], [], []]
# - - -
# file: 1335
# [['香蕉', '雜草'], ['花薊馬'], ['第滅寧', '陶斯松'], []]
# - - -
# file: 1321
# [['蕉農'], ['黑星病'], ['普克利', '凡殺護矽得', '亞托敏'], []]
# - - -
# file: 1309
# [['香蕉', '豆科', '茄科', '雜草'], ['嵌紋病', '萎縮病', '棉蚜', '蕉蚜', '蚜蟲'], ['加保扶'], []]
# - - -
# file: 11
# [['荔枝', '龍眼', '無患子科', '台灣欒樹'], ['荔枝椿象'], ['芬殺松', '加保利', '加保扶', '第滅寧'], ['宜蘭', '花蓮']]
# - - -
# file: 1241
# [['蕉農'], ['花薊馬'], ['第滅寧', '陶斯松', '福瑞松'], []]
# - - -
# file: 931
# [['水稻'], ['葉稻熱病', '稻熱病'], ['克熱賜圃', '加普胺', '嘉賜三賽唑', '富米熱斯', '保米熱斯', '護粒三賽唑'], ['桃園']]
# - - -
# file: 266
# [['葡萄'], ['白粉病'], ['依瑞菲克利', '滅芬農', '邁克尼'], ['臺中', '彰化']]
# - - -
# file: 500
# [['水稻'], ['葉稻熱病'], ['撲殺熱', '嘉賜三賽唑', '護粒三賽唑', '保米熱斯', '三賽唑', '加普胺'], ['苗栗']]
# - - -
# file: 1043
# [['水稻'], ['葉稻熱病', '稻熱病', '二化螟'], ['撲殺熱', '三賽唑', '護粒松', '喜樂克拉', '亞賜圃', '加普胺', '嘉賜三賽唑', '培丹', '芬普尼', '撲滅松', '陶斯松'], ['臺南']]
# - - -
# file: 1057
# [['檬果'], ['小黃薊馬', '薊馬'], ['丁基加保扶', '滅賜克', '賽洛寧', '賜諾特'], ['高雄', '屏東']]
# - - -
# file: 1030
# [['落花生'], ['秋行軍蟲'], [], ['彰化']]
# - - -
# file: 1018
# [['水稻'], ['稻熱病'], ['加普胺', '保米熱斯', '保米黴素', '嘉賜黴素', '熱必斯', '三賽唑'], ['花蓮']]
# - - -
# file: 567
# [['水稻'], ['白葉枯病'], ['克枯爛', '撲殺熱'], []]
# - - -
# file: 942
# [['水稻', '雜草'], ['瘤野螟'], ['布得芬諾', '矽護芬', '賽洛寧', '毆殺松'], ['臺北']]
# - - -
# file: 981
# [['水稻'], ['白葉枯病', '紋枯病'], ['賓得克利', '達滅淨', '維利黴素', '鏈四環黴素', '撲殺熱', '克枯爛', '鐵甲砷酸銨', '賓克隆', '三賽唑', '陶斯松', '毆殺松'], []]
# - - -
# file: 995
# [['水稻', '雜草'], ['水稻水象鼻蟲'], ['加保扶', '培丹'], ['桃園', '新竹', '苗栗', '臺中', '南投', '彰化', '花蓮']]
# - - -
# file: 76
# [['文旦', '果樹', '雜草'], ['灰象鼻蟲'], ['礦物油'], ['苗栗', '臺北']]
# - - -
# file: 62
# [['水稻', '雜草'], ['水稻水象鼻蟲', '螟蟲', '二化螟', '三化螟', '螟蛾'], ['培丹', '芬普尼', '撲滅松', '賽達松', '芬殺松', '益滅松', '免扶克', '加保扶', '丁基加保扶'], ['苗栗']]
# - - -
# file: 605
# [['水稻'], ['葉稻熱病'], [], ['嘉義', '臺南']]
# - - -
# file: 639
# [['柑桔', '麻豆文旦', '白柚', '椪柑', '柳丁'], ['薊馬', '小黃薊馬'], ['丁基加保扶', '賽洛寧'], ['臺南']]
# - - -
# file: 1144
# [['棗', '雜草'], ['疫病', '輪斑病', '果實蠅', '褐腐病'], ['硫酸銅', '亞磷酸', '銅滅達樂', '銅右滅達樂', '免賴得'], ['高雄']]
# - - -
# file: 1150
# [['水稻'], ['穗稻熱病', '稻熱病'], ['三賽唑', '護粒丹', '亞賜圃', '保米黴素'], ['高雄']]
# - - -
# file: 349
# [['馬鈴薯', '番茄'], ['晚疫病'], ['亞托敏', '達滅芬', '達滅克敏', '亞磷酸', '滅達樂'], ['臺南']]
# - - -
# file: 348
# [['洋香瓜'], ['銀葉粉蝨', '薊馬', '蚜蟲'], ['克凡派', '達特南', '第滅寧', '百利普芬'], ['臺南']]
# - - -
# file: 406
# [['水稻'], ['螟蟲', '飛蝨類', '褐飛蝨'], ['賽速安', '布芬淨', '派滅淨', '撲滅松', '陶斯松'], ['臺南']]
# - - -
# file: 1192
# [['蕉農'], ['黑星病'], ['鋅錳乃浦'], []]
# - - -
# file: 360
# [['洋香瓜'], ['銀葉粉蝨', '薊馬', '蚜蟲'], ['克凡派', '達特南', '第滅寧', '百利普芬'], ['臺南']]
# - - -
# file: 374
# [['蓮花'], ['小黃薊馬', '薊馬', '斜紋夜蛾'], ['亞滅培', '益達胺', '貝他賽扶寧', '蘇力菌', '亞磷酸+氫氧化鉀', '亞磷酸'], ['臺南']]
# - - -
# file: 1179
# [['蕉農'], [], ['普克利', '待克利', '環克座', '芬克座', '鋅錳乃浦', '礦物油'], []]
# - - -
# file: 1145
# [['荔枝', '龍眼', '欒樹'], ['荔枝椿象'], ['賽洛寧', '亞滅培', '丁基加保扶'], ['高雄']]
# - - -
# file: 638
# [['檬果'], ['炭疽病', '黑斑病', '蒂腐病', '果實蠅'], [], ['臺南']]
# - - -
# file: 604
# [['水稻', '雜草'], ['褐飛蝨', '煤煙病'], ['可尼丁'], ['臺東']]
# - - -
# file: 63
# [['水稻'], ['飛蝨類', '褐飛蝨', '白背飛蝨', '煤煙病', '草狀矮化病', '皺縮矮化病', '斑飛蝨', '水稻縞葉枯病'], ['賽速安', '布得芬諾', '可尼丁', '氟尼胺', '達特南', '矽護芬', '派滅淨'], ['苗栗']]
# - - -
# file: 837
# [['水稻', '雜草'], ['象鼻蟲', '水稻水象鼻蟲'], ['加保扶', '培丹'], ['花蓮']]
# - - -
# file: 957
# [['水稻'], ['葉稻熱病', '稻熱病'], ['撲殺熱', '三賽唑', '護粒松', '保米熱斯'], ['臺南', '嘉義']]
# - - -
# file: 572
# [['水稻'], ['穗稻熱病', '稻熱病', '褐飛蝨'], ['三賽唑', '加普胺'], ['臺東']]
# - - -
# file: 599
# [['水稻'], ['紋枯病', '白葉枯病'], ['矽酸爐渣', '菲克利', '賓克隆', '賓得克利', '依普座', '嘉賜克枯爛', '鐵甲砷酸銨', '三賽唑', '陶斯松', '毆殺松', '克枯三賽唑', '鏈四環黴素', '克枯爛', '撲殺熱'], ['臺東']]
# - - -
# file: 1031
# [[], ['荔枝椿象'], [], ['彰化']]
# - - -
# file: 558
# [['水稻'], ['穗稻熱病', '紋枯病', '稻熱病'], ['三賽唑', '賓克隆', '待克利', '福拉比'], []]
# - - -
# file: 955
# [['檬果'], ['白粉病', '葉蟬', '薊馬'], ['亞素靈', '達馬松'], []]
# - - -
# file: 799
# [['蔬菜', '萵苣', '甘藍', '花椰菜', '蘿蔔'], ['菌核病'], ['撲滅寧', '貝芬同'], ['臺南']]
# - - -
# file: 982
# [['水稻', '青蔥', '番石榴', '楊桃', '蔬果類', '果樹'], ['白葉枯病', '紋枯病', '甜菜夜蛾', '果實蠅', '疫病', '軟腐病', '露菌病', '根腐病'], [], ['臺南', '屏東', '花蓮', '宜蘭']]
# - - -
# file: 61
# [['水稻', '雜草'], ['螟蟲', '瘤野螟', '飛蝨類', '二化螟', '三化螟', '螟蛾', '白背飛蝨', '斑飛蝨', '褐飛蝨', '煤煙病', '草狀矮化病', '皺縮矮化病', '水稻縞葉枯病'], ['培丹', '芬普尼', '撲滅松', '賽達松', '芬殺松', '益滅松', '加保扶', '益達胺', '布芬第滅寧', '可尼丁', '布得芬諾', '賽洛寧'], ['苗栗']]
# - - -
# file: 1379
# [['印度棗'], ['白粉病'], ['三泰隆', '邁克尼', '平克座', '菲克利'], ['高雄', '屏東']]
# - - -
# file: 606
# [['水稻'], ['紋枯病'], [], ['嘉義']]
# - - -
# file: 174
# [['水稻'], ['稻熱病', '葉稻熱病'], [], ['高雄', '屏東', '花蓮']]
# - - -
# file: 1386
# [['水稻'], ['褐飛蝨', '黃條葉蚤'], ['達特南', '賽速安', '可尼丁'], ['高雄', '屏東']]
# - - -
# file: 1184
# [['檬果'], ['小黃薊馬', '薊馬'], ['丁基加保扶', '滅大松', '加保扶'], ['臺南']]
# - - -
# file: 377
# [['玉米', '禾本科雜草'], ['薊馬'], ['賜諾特', '撲滅松'], ['臺南']]
# - - -
# file: 405
# [['文旦柚', '棉花'], ['東方果實蠅', '果實蠅'], ['含毒甲基丁香油', '酵母球', '馬拉松', '賜諾殺'], ['臺南']]
# - - -
# file: 1152
# [['芒果'], ['炭疽病'], ['甲基多保淨', '扶吉胺', '得克利', '賽普護汰寧'], ['高雄']]
# - - -
# file: 149
# [['蔬菜', '果樹', '豆菜類'], ['疫病', '褐腐病', '軟腐病'], ['亞磷酸', '硫酸銅'], ['高雄']]
# - - -
# file: 613
# [['水稻'], ['紋枯病'], ['賓克隆', '福多寧', '菲克利', '維利熱必斯'], []]
# - - -
# file: 607
# [['洋香瓜', '番茄', '茄子', '芥藍菜', '芥菜', '白菜', '花椰菜', '蘿蔔', '蕪菁', '毛豆', '聖誕紅', '薰衣草', '西瓜', '葉菜類', '豆類', '瓜類', '園藝作物'], ['銀葉粉蝨', '粉介殼蟲', '黑煤病'], ['亞滅培', '益達胺', '派滅淨', '百利普芬', '第滅寧', '阿巴汀', '六伏隆', '畢芬寧', '布芬淨', '培丹', '印楝素'], []]
# - - -
# file: 808
# [['水稻'], ['葉稻熱病'], ['亞賜圃', '三賽唑', '富米熱斯', '保米黴素', '嘉賜黴素', '嘉賜三賽唑', '護粒三賽唑'], ['宜蘭']]
# - - -
# file: 48
# [['水稻'], ['葉稻熱病'], ['甲基多保淨', '嘉賜三賽唑', '護粒三賽唑', '保米熱斯', '三賽唑', '撲殺培丹'], ['苗栗']]
# - - -
# file: 983
# [['水稻'], ['紋枯病', '白葉枯病', '瘤野螟'], [], ['臺南', '嘉義']]
# - - -
# file: 773
# [['十字花科', '蔬菜', '葉菜類', '蘿蔔', '油菜'], ['紋白蝶', '黃條葉蚤'], ['蘇力菌', '白殭菌', '綠殭菌', '祿芬隆', '傑他賽滅寧', '因滅汀', '賽洛寧', '畢芬寧', '第滅寧', '陶斯松', '達特南', '亞滅培', '佈飛松', '培丹', '阿巴汀', '免速達', '毆殺滅'], ['臺南']]
# - - -
# file: 954
# [['蘇鐵'], ['白輪盾介殼蟲'], [], ['臺北', '桃園']]
# - - -
# file: 1224
# [['番茄', '茄子', '甜椒', '辣椒', '馬鈴薯', '茄科'], ['番茄潛旋蛾', '蛾類'], ['第滅寧', '畢芬寧', '亞滅培', '賜諾殺', '阿巴汀', '因滅汀', '克凡派', '因得克'], ['雲林', '南投']]
# - - -
# file: 559
# [['水稻'], ['徒長病'], [], ['臺東']]
# - - -
# file: 565
# [['水稻'], ['褐飛蝨'], ['益達胺', '布芬淨', '布芬第滅寧'], []]
# - - -
# file: 203
# [['水稻'], ['瘤野螟'], ['賽速洛寧', '布得芬諾', '培丹'], ['臺中']]
# - - -
# file: 217
# [['荔枝', '果樹', '柑橘', '番石榴', '龍眼', '楊桃', '蓮霧', '橄欖', '枇杷', '柿子'], ['黑角舞蛾'], ['賽洛寧', '第滅寧'], ['臺中', '南投', '彰化']]
# - - -
# file: 1026
# [['雜糧', '綠肥作物'], ['斜紋夜蛾'], ['性費洛蒙'], ['彰化']]
# - - -
# file: 575
# [['水稻'], ['葉稻熱病', '負泥蟲', '稻熱病'], ['三賽唑', '保米熱斯', '嘉賜貝芬', '益滅松', '加保扶', '納乃得'], ['臺東']]
# - - -
# file: 207
# [['水稻'], ['葉稻熱病'], ['撲殺熱', '三賽唑', '亞賜圃', '嘉賜三賽唑', '加普胺', '護粒松'], ['臺中']]
# - - -
# file: 944
# [['綠肥作物', '田菁', '雜草'], ['斜紋夜蛾'], ['性費洛蒙', '芬化利', '賽洛寧'], ['桃園']]
# - - -
# file: 1208
# [['蕉農', '雜草'], ['花薊馬', '水銹斑'], ['第滅寧', '陶斯松', '福瑞松'], []]
# - - -
# file: 1220
# [['蕉株'], ['花薊馬', '水銹斑'], ['第滅寧', '陶斯松'], []]
# - - -
# file: 978
# [['水稻'], ['紋枯病', '白葉枯病'], [], []]
# - - -
# file: 763
# [['落花生', '葉菜類', '田菁', '毛豆', '大蒜', '青蔥', '甘藷', '玉米', '花卉'], ['斜紋夜蛾', '銹病', '葉斑病'], ['性費洛蒙', '蘇力菌', '四氯福多寧', '滅特座', '亞托敏', '環克座', '得克利', '菲克利', '比多農', '四氯異苯腈', '鋅錳乃浦', '錳乃浦'], ['臺南']]
# - - -
# file: 58
# [['柑桔', '柑橘'], ['薊馬', '小黃薊馬', '花薊馬'], ['丁基加保扶'], ['苗栗']]
# - - -
# file: 1397
# [['水稻'], ['穗稻熱病', '紋枯病', '螟蟲', '葉稻熱病', '稻熱病', '大螟', '二化螟'], [], ['雲林', '臺南']]
# - - -
# file: 429
# [['水稻'], ['葉稻熱病', '白葉枯病', '稻熱病'], ['撲殺熱', '三賽唑', '喜樂克拉', '丙基喜樂松', '護粒松', '芬諾尼', '嘉賜克枯爛', '克枯三賽唑', '克枯爛', '鏈四環黴素'], ['臺南', '嘉義']]
# - - -
# file: 1181
# [['蕉農', '雜草'], ['花薊馬', '水銹斑'], ['第滅寧', '陶斯松'], []]
# - - -
# file: 372
# [['水稻'], ['穗稻熱病'], ['三賽唑', '保米黴素', '加普胺', '喜樂克拉', '富米熱斯'], ['臺南', '嘉義']]
# - - -
# file: 400
# [['水稻'], ['穗稻熱病', '紋枯病', '葉稻熱病', '稻熱病'], ['護粒丹', '三賽唑', '丙基喜樂松', '嘉賜黴素', '喜樂克拉', '護粒松', '賓克隆', '福多寧', '菲克利', '維利熱必斯', '貝芬同'], ['臺南', '嘉義']]
# - - -
# file: 428
# [['果樹', '番石榴', '楊桃', '蓮霧', '芒果', '柑桔', '棉花'], ['果實蠅', '東方果實蠅'], ['含毒甲基丁香油', '酵母球', '馬拉松', '賜諾殺'], ['臺南']]
# - - -
# file: 1396
# [[], ['東方果實蠅'], ['含毒甲基丁香油'], ['雲林', '臺南']]
# - - -
# file: 158
# [['芒果'], ['白粉病', '黑斑病', '炭疽病', '螟蛾', '小黃薊馬', '葉蟬', '煤煙病'], [], ['高雄']]
# - - -
# file: 1355
# [['香蕉'], ['黑星病'], ['鋅錳乃浦', '待克利', '亞托敏'], []]
# - - -
# file: 825
# [['青蔥', '蔬菜'], ['甜菜夜蛾'], ['因滅汀', '得芬諾', '核多角體病毒', '黑殭菌', '性費洛蒙'], ['宜蘭', '花蓮']]
# - - -
# file: 1235
# [['蕉株'], ['花薊馬', '水銹斑'], ['第滅寧', '陶斯松', '福瑞松'], []]
# - - -
# file: 1221
# [['水稻'], ['葉稻熱病', '稻熱病'], ['三賽唑', '喜樂克拉', '丙基喜樂松', '護粒松', '撲殺熱'], ['雲林', '臺南']]
# - - -
# file: 945
# [['水稻'], ['葉稻熱病', '稻熱病'], ['克熱賜圃', '加普胺', '嘉賜三賽唑', '富米熱斯', '保米熱斯', '護粒三賽唑', '亞賜圃'], ['桃園', '新竹']]
# - - -
# file: 560
# [['水稻'], ['象鼻蟲', '水稻水象鼻蟲'], ['益達胺', '加保扶', '培丹', '丁基加保扶'], ['臺東', '桃園', '新竹', '苗栗', '南投']]
# - - -
# file: 212
# [['水稻'], ['穗稻熱病', '稻熱病'], ['三賽唑', '亞賜圃', '嘉賜三賽唑', '加普胺', '護粒松'], ['彰化', '南投', '臺中']]
# - - -
# file: 548
# [['水稻'], ['白背飛蝨', '褐飛蝨', '飛蝨類'], ['賽速安', '可尼丁', '派滅淨', '達特南'], ['臺中', '彰化']]
# - - -
# file: 1035
# [[], ['東方果實蠅', '果實蠅'], ['含毒甲基丁香油'], ['臺中']]
# - - -
# file: 1021
# [['蔬菜', '雜糧', '豆類'], ['斜紋夜蛾'], ['性費洛蒙'], []]
# - - -
# file: 238
# [['番茄', '馬鈴薯'], ['晚疫病'], [], ['臺中']]
# - - -
# file: 204
# [['水稻'], ['褐飛蝨'], ['氟尼胺', '賽速安', '可尼丁', '派滅淨', '達特南'], ['臺中', '彰化']]
# - - -
# file: 210
# [['柑桔'], ['黑星病'], ['腈硫克敏', '免得爛', '鋅錳乃浦', '甲基鋅乃浦', '免賴得', '腈硫醌', '礦物油'], ['臺中']]
# - - -
# file: 947
# [['水稻'], ['白葉枯病'], ['克枯爛', '鏈四環黴素'], ['桃園']]
# - - -
# file: 953
# [['果樹', '鳳梨', '番石榴'], ['果實蠅'], [], []]
# - - -
# file: 1223
# [[], ['琉璃蟻', '介殼蟲', '蚜蟲', '螞蟻', '疣胸琉璃蟻'], [], ['雲林']]
# - - -
# file: 827
# [['水稻'], ['紋枯病', '白葉枯病'], ['待克利', '賓克隆', '滅普寧', '福多寧', '滅紋', '鐵甲砷酸銨', '維利黴素', '撲殺熱', '克枯爛', '鏈四環黴素'], ['花蓮']]
# - - -
# file: 1343
# [['蕉農'], [], [], ['嘉義']]
# - - -
# file: 614
# [['檬果', '荔枝', '龍眼', '番石榴', '楊桃', '果樹'], ['東方果實蠅', '果實蠅'], ['含毒甲基丁香油', '蛋白質水解物', '馬拉松', '芬殺松', '三氯松'], ['臺南']]
# - - -
# file: 1394
# [['水稻'], ['稻熱病', '穗稻熱病'], [], ['雲林', '臺南']]
# - - -
# file: 98
# [['水稻'], ['白葉枯病'], [], ['桃園']]
# - - -
# file: 166
# [['番茄', '茄科', '馬鈴薯'], ['晚疫病', '早疫病'], ['亞磷酸', '氫氧化銅', '鹼性氯氧化銅', '嘉賜銅', '亞托敏', '凡殺克絕', '達滅芬'], ['高雄']]
# - - -
# file: 1169
# [['蕉農', '豆科', '茄科', '雜草'], ['嵌紋病', '胡瓜嵌紋病毒', '蚜蟲'], ['益達胺'], []]
# - - -
# file: 364
# [['水稻'], ['稻熱病', '葉稻熱病'], ['撲殺熱', '三賽唑', '亞賜圃', '喜樂克拉', '加普胺', '護粒松'], ['臺南']]
# - - -
# file: 402
# [['文旦', '白柚', '芸香科', '果樹'], ['柑橘窄胸天牛'], [], ['臺南']]
# - - -
# file: 1183
# [['芒果', '雜草'], ['小黃薊馬', '薊馬'], ['丁基加保扶', '芬殺松', '滅大松', '納乃得', '加保扶'], ['臺南']]
# - - -
# file: 1154
# [['果樹', '荔枝', '檸檬', '番石榴', '木瓜', '紅龍果', '柑桔'], ['露疫病', '酸腐病', '潰瘍病', '炭疽病', '黑星病', '瘡痂病', '疫病', '根腐病', '褐腐病', '黑腐病'], ['中性化亞磷酸', '賽普護汰寧', '得克利'], ['高雄']]
# - - -
# file: 1168
# [['香蕉'], ['花薊馬', '水銹病', '水銹斑'], ['陶斯松', '第滅寧'], []]
# - - -
# file: 99
# [['水稻'], ['葉稻熱病', '稻熱病'], [], ['桃園']]
# - - -
# file: 1395
# [['水稻'], ['穗稻熱病', '紋枯病', '稻熱病'], [], ['雲林', '臺南']]
# - - -
# file: 601
# [['水稻', '胡麻'], ['胡麻葉枯病', '葉稻熱病', '稻熱病', '紋枯病', '白葉枯病', '穗稻熱病'], ['矽酸爐渣', '克熱淨', '普克利', '鋅錳乃浦', '錳乃浦'], ['臺東', '高雄']]
# - - -
# file: 167
# [['蜜棗', '雜草', '棗'], ['疫病', '輪斑病', '褐腐病'], ['亞磷酸', '硫酸銅', '免賴得'], ['高雄']]
# - - -
# file: 173
# [['芒果', '雜草'], ['小黃薊馬', '薊馬'], ['丁基加保扶', '滅大松', '納乃得', '滅賜克', '賜諾特'], ['臺南']]
# - - -
# file: 629
# [['楊桃'], ['細菌性斑點病'], ['鹼性氯氧化銅', '多保鏈黴素', '波爾多液', '銅快得寧', '鋅波爾多'], ['臺南']]
# - - -
# file: 1356
# [['蕉株', '雜草'], ['花薊馬'], ['賽洛寧', '陶斯松'], []]
# - - -
# file: 8
# [['蔬菜', '青蔥'], ['斜紋夜蛾', '甜菜夜蛾'], ['性費洛蒙', '微生物製劑', '蘇力菌', '核多角體病毒'], ['花蓮', '宜蘭']]
# - - -
# file: 826
# [['水稻', '蔬菜', '玉米', '落花生', '果樹'], ['軟腐病', '疫病', '炭疽病', '斜紋夜蛾'], [], []]
# - - -
# file: 832
# [['水稻', '雜草'], ['葉稻熱病', '負泥蟲', '水稻水象鼻蟲'], ['撲殺熱', '克氯綜', '丙基喜樂松', '熱必斯', '三賽唑', '保米黴素', '嘉賜三賽唑', '保米熱斯', '亞賜圃', '益滅松', '撲滅松', '益滅蝨', '加保扶', '培丹', '丁基加保扶'], ['花蓮']]
# - - -
# file: 1222
# [['水稻'], ['穗稻熱病', '稻熱病'], [], ['雲林']]
# - - -
# file: 952
# [[], ['晚疫病'], [], ['臺南']]
# - - -
# file: 211
# [['葡萄'], ['露菌病'], ['達滅芬', '氟比拔克', '銅滅達樂', '鋅錳克絕', '甲鋅毆殺斯'], ['臺中']]
# - - -
# file: 577
# [['水稻'], ['褐飛蝨'], ['依芬寧', '布芬淨', '布芬第滅寧'], ['臺東']]
# - - -
# file: 205
# [['洋桔梗', '花卉'], ['露菌病'], ['本達樂'], ['臺中']]
# - - -
# file: 1020
# [['果樹', '芒果', '荔枝'], ['東方果實蠅', '果實蠅'], ['含毒甲基丁香油', '賜諾殺', '含毒蛋白質水解物'], ['彰化', '屏東']]
# - - -
# file: 208
# [['荔枝', '果樹', '柑橘', '番石榴', '龍眼', '楊桃', '蓮霧', '橄欖', '枇杷', '柿子'], ['黑角舞蛾'], ['賽洛寧', '第滅寧'], ['臺中', '彰化', '南投']]
# - - -
# file: 787
# [['木瓜', '番茄', '樹薯', '朱槿'], ['秀粉介殼蟲', '煤煙病', '介殼蟲'], ['馬拉松', '礦物油'], ['臺南']]
# - - -
# file: 793
# [['馬鈴薯', '水稻', '番茄'], ['青枯病', '晚疫病', '瘡痂病'], [], []]
# - - -
# file: 1367
# [['水稻'], ['瘤野螟', '白葉枯病'], ['撲殺培丹', '培丹', '貝他賽扶寧', '賽洛寧', '第滅寧'], ['屏東', '高雄']]
# - - -
# file: 43
# [['水稻'], ['葉稻熱病'], ['甲基多保淨', '嘉賜三賽唑', '護粒三賽唑', '保米熱斯', '三賽唑', '撲殺培丹'], ['苗栗']]
# - - -
# file: 156
# [['番茄'], ['晚疫病'], ['氫氧化銅', '鹼性氯氧化銅', '嘉賜銅', '亞托敏', '凡殺克絕', '亞磷酸'], ['高雄']]
# - - -
# file: 94
# [['水稻'], ['飛蝨類', '白背飛蝨'], ['加保利', '丁基加保扶', '免敵克', '免扶克', '加保扶'], ['桃園']]
# - - -
# file: 1171
# [['蕉農'], [], ['普克利', '待克利', '環克座', '芬克座', '鋅錳乃浦', '礦物油'], []]
# - - -
# file: 354
# [['蓮花'], ['小黃薊馬', '薊馬', '斜紋夜蛾'], ['亞滅培', '益達胺', '貝他賽扶寧', '蘇力菌'], ['臺南']]
# - - -
# file: 432
# [['水稻'], ['稻熱病', '葉稻熱病'], ['三賽唑', '喜樂克拉', '丙基喜樂松', '護粒松', '撲殺熱'], ['臺南', '嘉義']]
# - - -
# file: 340
# [['水稻'], ['白葉枯病'], ['嘉賜克枯爛', '克枯三賽唑', '克枯爛', '鏈四環黴素', '撲殺熱'], ['臺南']]
# - - -
# file: 368
# [['芒果'], ['畸形病'], [], ['臺南']]
# - - -
# file: 341
# [['芒果'], ['小黃薊馬', '薊馬'], ['克凡派', '滅賜克', '畢芬寧', '賽洛寧', '芬普尼', '益達胺', '賜諾特'], ['臺南']]
# - - -
# file: 355
# [['水稻'], ['白葉枯病'], ['嘉賜克枯爛', '克枯三賽唑', '克枯爛', '鏈四環黴素', '撲殺熱'], ['臺南', '嘉義']]
# - - -
# file: 396
# [['水稻'], ['稻熱病', '葉稻熱病'], ['護粒丹', '三賽唑', '亞賜圃', '喜樂克拉', '護粒松'], ['臺南', '嘉義']]
# - - -
# file: 802
# [['水稻', '雜草'], ['葉稻熱病', '水稻水象鼻蟲'], ['甲基多保淨', '嘉賜三賽唑', '護粒三賽唑', '保米熱斯', '三賽唑', '加普胺', '培丹', '免扶克', '加保扶', '丁基加保扶'], ['苗栗']]
# - - -
# file: 4
# [['水稻'], ['瘤野螟'], ['蘇力菌', '苦楝油'], ['花蓮']]
# - - -
# file: 180
# [['香蕉', '蔬菜', '青蔥', '果樹', '水稻', '龍鬚菜', '韭菜', '甘藍', '葉菜類', '西瓜', '芋頭', '文旦柚', '雜糧', '甘藷', '柑桔'], ['疫病', '白絹病', '軟腐病', '炭疽病', '潰瘍病'], [], ['花蓮', '宜蘭']]
# - - -
# file: 1372
# [['水稻'], ['穗稻熱病', '稻熱病', '葉稻熱病'], ['加普胺', '嘉賜三賽唑', '保米熱斯', '保米賜圃'], ['高雄']]
# - - -
# file: 989
# [['竹筍'], ['竹盲椿象'], ['撲芬松', '芬化利', '滅賜松'], ['臺南']]
# - - -
# file: 751
# [['果樹', '芒果', '龍眼', '番石榴', '楊桃'], ['東方果實蠅', '果實蠅'], ['含毒甲基丁香油', '賜諾殺'], []]
# - - -
# file: 976
# [['水稻'], ['潛蠅類', '亞洲潛葉蠅'], [], []]
# - - -
# file: 962
# [['薇甘菊', '林木', '菊科', '雜草'], [], [], ['花蓮']]
# - - -
# file: 792
# [['木瓜'], ['黑腐病', '果疫病'], ['嘉賜銅'], ['臺南']]
# - - -
# file: 1212
# [['香蕉'], ['嵌紋病'], [], []]
# - - -
# file: 786
# [['水稻', '雜草'], ['瘤野螟'], ['芬普尼', '剋安勃', '賽速安勃', '布得芬諾', '毆殺松', '賽洛寧'], ['臺南', '嘉義']]
# - - -
# file: 221
# [['水稻'], ['穗稻熱病', '二化螟', '稻熱病'], ['三賽唑', '亞賜圃', '嘉賜三賽唑', '加普胺', '護粒松', '培丹', '芬普尼', '撲滅松'], ['彰化', '南投', '臺中']]
# - - -
# file: 584
# [['水稻'], ['白葉枯病'], ['克枯爛', '撲殺熱'], ['臺東']]
# - - -
# file: 551
# [['水稻'], ['徒長病'], [], ['臺東']]
# - - -
# file: 948
# [['水稻'], ['稻熱病', '苗立枯病', '徒長病', '胡麻葉枯病', '線蟲白尖病', '線蟲', '根瘤線蟲', '立枯病', '水稻水象鼻蟲', '福壽螺'], [], ['桃園']]
# - - -
# file: 1210
# [['蕉農'], ['黑星病'], ['凡殺護矽得', '待克利', '腐絕'], []]
# - - -
# file: 974
# [['水稻', '雜草'], ['水稻水象鼻蟲'], ['丁基加保扶', '益達胺', '加保扶', '免扶克', '培丹'], ['桃園', '臺北']]
# - - -
# file: 1370
# [['蓮霧', '印度棗', '木瓜', '瓜果類', '茄果類', '蔬菜', '玫瑰', '林木', '果樹', '雜糧', '觀賞植物', '雜草', '柑桔'], ['葉螨', '柑桔銹螨'], [], ['高雄']]
# - - -
# file: 182
# [['玉米', '雜草'], ['薊馬'], ['賜諾特', '撲滅松', '納乃得'], ['雲林']]
# - - -
# file: 196
# [['荔枝', '果樹', '龍眼', '楊桃', '蓮霧', '番石榴', '柑橘', '橄欖', '枇杷', '柿子'], ['黑角舞蛾'], ['賽洛寧', '第滅寧'], ['臺中', '南投', '彰化']]
# - - -
# file: 1358
# [['水稻'], ['穗稻熱病', '紋枯病'], [], []]
# - - -
# file: 169
# [['龍眼', '荔枝', '欒樹'], ['荔枝椿象'], ['賽洛寧', '亞滅培', '丁基加保扶'], ['高雄']]
# - - -
# file: 425
# [['水稻'], ['穗稻熱病', '稻熱病'], ['三賽唑', '喜樂克拉', '丙基喜樂松', '甲基多保淨', '護粒松'], ['臺南']]
# - - -
# file: 357
# [['木瓜', '柑桔', '柑橘', '果樹'], ['果疫病', '褐腐病'], ['達滅芬', '亞托敏', '賽座滅', '嘉賜銅', '純白鏈黴菌素', '亞磷酸', '硫酸銅', '福賽得', '鋅錳滅達樂'], ['臺南']]
# - - -
# file: 419
# [['水稻'], ['穗稻熱病', '紋枯病', '稻熱病'], ['三賽唑', '喜樂克拉', '丙基喜樂松', '賓克隆', '福多寧', '菲克利', '維利熱必斯', '貝芬同'], ['臺南', '嘉義']]
# - - -
# file: 418
# [['水稻'], ['穗稻熱病', '稻熱病'], ['三賽唑', '喜樂克拉', '丙基喜樂松'], ['臺南', '嘉義']]
# - - -
# file: 356
# [['水稻'], ['白葉枯病', '紋枯病'], ['嘉賜克枯爛', '克枯三賽唑', '克枯爛', '鏈四環黴素', '撲殺熱', '賓克隆', '福多寧', '菲克利', '維利熱必斯'], ['臺南', '嘉義']]
# - - -
# file: 395
# [['水稻'], ['稻熱病'], ['護粒丹', '三賽唑', '亞賜圃', '喜樂克拉', '加普胺', '護粒松'], ['臺南', '嘉義']]
# - - -
# file: 632
# [['蓮花', '柑桔', '檬果', '蘭花'], ['小黃薊馬', '薊馬'], ['亞滅培', '芬普尼', '益達胺'], ['臺南']]
# - - -
# file: 626
# [['水稻'], ['葉稻熱病', '稻熱病'], ['撲殺熱', '三賽唑', '護粒松', '喜樂克拉', '加普胺', '嘉賜三賽唑'], ['臺南']]
# - - -
# file: 1359
# [['水稻', '雜草'], ['紋枯病', '白葉枯病'], ['賓得克利', '賓克隆', '福多寧', '待克利', '鏈四環黴素', '撲殺熱', '克枯爛', '鐵甲砷酸銨', '三賽唑', '陶斯松', '毆殺松'], []]
# - - -
# file: 1211
# [['蕉農'], ['花薊馬', '水銹斑'], ['第滅寧', '陶斯松'], []]
# - - -
# file: 578
# [['水稻'], ['瘤野螟'], ['毆殺松', '陶斯松'], ['臺東']]
# - - -
# file: 550
# [['水稻'], ['葉稻熱病', '稻熱病'], ['三賽唑', '保米熱斯', '嘉賜貝芬'], []]
# - - -
# file: 1013
# [['綠肥作物', '蔬菜', '雜糧', '豆類'], ['斜紋夜蛾'], ['性費洛蒙'], ['雲林', '嘉義']]
# - - -
# file: 1003
# [['水稻'], ['福壽螺'], ['聚乙醛', '耐克螺'], []]
# - - -
# file: 1017
# [['洋香瓜', '瓜類'], ['薊馬', '蚜蟲'], [], ['臺南']]
# - - -
# file: 554
# [['水稻', '玉米', '甘庶', '茭白荀', '小麥', '牧草', '禾本科雜草'], ['瘤野螟', '水稻水象鼻蟲'], ['培丹', '加保扶', '丁基加保扶'], ['桃園', '新竹', '苗栗', '南投']]
# - - -
# file: 232
# [['梨', '龍柏'], ['赤星病'], ['滅普寧', '得克利', '芬瑞莫', '三泰芬', '比多農', '三氟敏', '克熱淨'], ['臺中']]
# - - -
# file: 226
# [['荔枝', '龍眼'], ['荔枝銹螨', '荔枝椿象', '腫葉病', '毛氈病', '酸腐病', '鬼帚病'], ['加保扶', '可濕性硫磺', '加保利', '芬殺松'], ['臺中', '南投']]
# - - -
# file: 540
# [['荔枝', '龍眼'], ['荔枝細蛾'], ['益洛寧', '陶斯寧', '加保利', '陶斯松', '第滅寧', '芬殺松', '撲滅松', '加保扶'], ['臺中', '南投', '彰化']]
# - - -
# file: 971
# [['水稻', '果樹'], ['紋枯病', '白葉枯病', '軟腐病', '疫病', '露菌病', '黑腐病', '果實蠅'], [], []]
# - - -
# file: 959
# [['水稻'], ['穗稻熱病', '稻熱病', '葉稻熱病', '節稻熱病'], ['熱必斯', '富米熱斯', '亞賜圃', '保米賜圃', '加普胺', '護粒丹'], ['臺東']]
# - - -
# file: 1215
# [['香蕉'], ['嵌紋病'], [], []]
# - - -
# file: 756
# [['洋香瓜', '瓜類'], ['瓜類退綠黃化病毒', '銀葉粉蝨', '薊馬', '蚜蟲', '紋白蝶', '瓜實蠅'], [], ['臺南']]
# - - -
# file: 811
# [['蓮霧', '番石榴', '果樹'], ['果實蠅', '甜菜夜蛾'], [], ['宜蘭']]
# - - -
# file: 839
# [['水稻'], ['稻熱病'], ['富米熱斯', '熱必斯', '三賽唑', '嘉賜三賽唑', '護粒丹', '亞賜圃', '保米賜圃', '加普胺', '撲殺熱'], ['花蓮']]
# - - -
# file: 346
# [['葫蘆科', '胡瓜', '絲瓜', '洋香瓜', '十字花科', '菠菜', '萵苣', '青蔥', '葉菜類', '瓜類', '菊科', '蔥科', '蔬菜'], ['露菌病'], ['亞托敏', '達滅芬', '鋅錳座賽胺'], ['臺南']]
# - - -
# file: 353
# [['芒果'], ['小黃薊馬', '薊馬'], ['礦物油'], ['臺南']]
# - - -
# file: 347
# [['大蒜', '蔥', '洋蔥', '韭菜', '百合', '唐菖浦'], ['薊馬'], ['毆殺滅', '貝他賽扶寧'], ['臺南']]
# - - -
# file: 1189
# [['蕉農'], ['黑星病'], ['普克利', '鋅錳乃浦', '礦物油'], []]
# - - -
# file: 384
# [['木瓜', '柑桔', '蔬果類', '水稻'], ['果疫病', '褐腐病', '疫病', '炭疽病', '蒂腐病', '果腐病', '細菌性斑點病', '軟腐病', '果斑病', '潰瘍病', '白葉枯病'], [], ['臺南']]
# - - -
# file: 637
# [['水稻'], ['穗稻熱病', '紋枯病', '稻熱病'], ['三賽唑', '保米熱斯', '嘉賜三賽唑', '加普胺', '克熱淨', '保米賜圃', '賓克隆', '福多寧', '菲克利', '維利熱必斯'], []]
# - - -
# file: 623
# [['洋香瓜'], ['白粉病'], ['克熱淨', '快諾芬', '賽普洛', '平克座', '賽普待克利', '四克利', '克收欣', '得克利', '達克利', '普得松', '依滅列', '芬瑞莫'], ['臺南']]
# - - -
# file: 1374
# [['蓮霧'], ['炭疽病', '果腐病', '疫病'], ['亞托敏', '克熱淨', '白列克敏', '三氟敏', '賽座滅', '凡殺克絕'], ['高雄', '屏東']]
# - - -
# file: 2
# [['雜草'], ['斜紋夜蛾', '甜菜夜蛾'], ['性費洛蒙'], ['宜蘭']]
# - - -
# file: 804
# [['水稻', '雜草'], ['螟蟲', '二化螟', '三化螟', '水稻水象鼻蟲', '象鼻蟲', '螟蛾'], ['培丹', '芬普尼', '撲滅松', '賽達松', '加保扶', '芬殺松', '益滅松', '免扶克', '丁基加保扶'], ['苗栗']]
# - - -
# file: 1348
# [['蕉株', '雜草'], ['花薊馬'], ['第滅寧', '陶斯松'], []]
# - - -
# file: 743
# [['馬鈴薯', '番茄'], ['晚疫病'], ['滅達樂'], []]
# - - -
# file: 757
# [['水稻'], ['葉稻熱病', '稻熱病'], ['撲殺熱', '三賽唑', '護粒松', '喜樂克拉', '亞賜圃', '加普胺', '嘉賜三賽唑'], []]
# - - -
# file: 1214
# [['蕉農'], ['花薊馬', '水銹斑'], ['第滅寧', '陶斯松'], []]
# - - -
# file: 958
# [['水稻', '雜糧', '果樹', '蔬菜'], ['稻熱病', '葉稻熱病', '穗稻熱病', '紋枯病', '白葉枯病', '螟蟲'], [], ['花蓮']]
# - - -
# file: 794
# [['洋香瓜'], ['薊馬', '銀葉粉蝨', '蚜蟲'], ['克凡派', '達特南', '第滅寧', '百利普芬'], ['臺南']]
# - - -
# file: 1200
# [['蕉農'], ['花薊馬', '水銹斑'], ['第滅寧', '陶斯松', '福瑞松'], []]
# - - -
# file: 964
# [['水稻'], ['穗稻熱病', '稻熱病'], ['加普胺', '三賽唑', '富米熱斯', '保米熱斯'], ['苗栗']]
# - - -
# file: 227
# [['水稻'], ['葉稻熱病'], ['撲殺熱', '三賽唑', '亞賜圃', '嘉賜三賽唑', '加普胺', '護粒松'], ['臺中']]
# - - -
# file: 541
# [['甜柿'], ['角斑病'], ['邁克尼', '百克敏', '克熱淨'], ['臺中', '彰化', '南投']]
# - - -
# file: 555
# [['水稻'], ['白葉枯病', '稻熱病', '紋枯病', '瘤野螟'], ['撲殺熱', '克枯爛', '三賽唑', '維利黴素', '依普座', '毆殺松', '賽洛寧', '鐵甲砷酸銨', '賓克隆', '陶斯松'], ['臺東']]
# - - -
# file: 569
# [['水稻'], ['葉稻熱病', '稻熱病'], ['三賽唑', '保米熱斯', '嘉賜貝芬'], ['臺東']]
# - - -
# file: 1002
# [['水稻', '蔬菜', '果樹', '芒果'], ['疫病', '稻熱病', '軟腐病', '露菌病', '黑腐病', '斜紋夜蛾', '果實蠅', '果斑病'], ['含毒甲基丁香油'], []]
# - - -
# file: 596
# [['果樹', '釋迦', '文旦柚', '番荔枝', '水稻', '雜草', '雜糧', '樹豆', '洛神葵', '蔬菜', '花卉', '胡瓜', '苦瓜', '扁蒲', '番茄', '豇豆', '蔓性作物', '蕹菜', '秋葵', '甘藷', '花椰菜', '結球白菜', '甘藍', '荖花', '荖葉'], [], [], ['臺東']]
# - - -
# file: 543
# [['梨', '龍柏'], ['赤星病'], ['得克利', '富爾邦', '芬瑞莫', '三泰芬', '比多農'], ['臺中']]
# - - -
# file: 231
# [['番茄'], ['晚疫病'], [], ['臺中', '彰化']]
# - - -
# file: 557
# [['水稻'], ['葉稻熱病', '稻熱病'], ['三賽唑', '保米熱斯', '嘉賜貝芬'], []]
# - - -
# file: 966
# [['草莓', '番茄', '甜椒', '胡瓜', '向日葵'], ['斜紋夜蛾'], ['性費洛蒙', '佈飛百滅寧', '佈飛賽滅寧', '畢芬寧', '撲滅芬普寧'], ['苗栗']]
# - - -
# file: 769
# [['馬鈴薯', '番茄'], ['晚疫病'], ['亞托敏', '達滅芬', '達滅克敏', '滅達樂'], []]
# - - -
# file: 812
# [['雜糧', '玉米', '高粱', '薏苡', '水稻', '甘蔗', '牧草'], ['秋行軍蟲'], ['性費洛蒙'], ['宜蘭']]
# - - -
# file: 1362
# [['水稻'], ['白葉枯病', '紋枯病', '稻熱病'], [], ['屏東']]
# - - -
# file: 91
# [['水稻'], ['葉稻熱病', '稻熱病'], [], ['桃園']]
# - - -
# file: 621
# [['洋香瓜'], ['白粉病'], ['克熱淨', '快諾芬', '賽普洛', '平克座', '賽普待克利', '四克利', '克收欣', '得克利', '達克利', '普得松', '依滅列', '芬瑞莫'], ['臺南']]
# - - -
# file: 1160
# [['蓮霧'], ['黑腐病', '果腐病', '炭疽病'], ['扶吉胺', '白列克敏', '賽普護汰寧'], ['高雄']]
# - - -
# file: 386
# [['蓮花'], ['小黃薊馬', '薊馬', '斜紋夜蛾'], ['亞滅培', '益達胺', '貝他賽扶寧', '蘇力菌'], ['臺南']]
# - - -
# file: 1174
# [['蕉農'], [], ['鋅錳乃浦'], []]
# - - -
# file: 379
# [['檬果', '果樹'], ['炭疽病', '白粉病'], ['貝芬依滅列', '賽普待克利', '克熱淨', '免得爛', '撲克拉'], ['臺南']]
# - - -
# file: 422
# [['荔枝', '龍眼'], ['荔枝椿象'], ['賽洛寧'], ['臺南']]
# - - -
# file: 378
# [['芒果'], ['小黃薊馬', '薊馬'], ['礦物油', '克凡派', '滅賜克', '畢芬寧', '賽洛寧', '芬普尼', '益達胺', '賜諾特'], ['臺南']]
# - - -
# file: 1149
# [['洋蔥'], ['炭疽病'], ['百克敏'], ['高雄', '屏東']]
# - - -
# file: 146
# [['荔枝', '龍眼', '無患子科'], ['荔枝椿象', '露疫病'], ['陶斯松', '賽洛寧', '丁基加保扶'], ['高雄']]
# - - -
# file: 608
# [['荔枝'], ['露疫病', '酸腐病'], ['腈硫醌銅', '快得寧', '菲克利'], []]
# - - -
# file: 1377
# [['水稻'], ['葉稻熱病', '稻熱病'], ['加普胺', '嘉賜三賽唑'], ['高雄']]
# - - -
# file: 1363
# [['水稻'], ['稻熱病'], ['加普胺', '嘉賜三賽唑'], ['屏東', '高雄']]
# - - -
# file: 47
# [['荔枝', '龍眼'], ['荔枝椿象', '鬼帚病', '露疫病'], ['芬殺松', '加保利', '加保扶', '第滅寧'], ['苗栗']]
# - - -
# file: 53
# [['水稻', '雜草'], ['螟蟲', '瘤野螟', '飛蝨類', '二化螟', '三化螟', '螟蛾', '白背飛蝨', '斑飛蝨', '褐飛蝨', '煤煙病', '草狀矮化病', '皺縮矮化病', '水稻縞葉枯病'], ['培丹', '芬普尼', '撲滅松', '賽達松', '加保扶', '芬殺松', '益滅松', '益達胺', '布芬第滅寧', '可尼丁', '布得芬諾', '賽洛寧'], ['苗栗']]
# - - -
# file: 768
# [['番茄'], ['番茄嵌紋病毒', '胡瓜嵌紋病毒', '番茄黃化捲葉病毒', '馬鈴薯病毒Y', '番茄斑點萎凋病毒', '薊馬', '銀葉粉蝨', '蚜蟲'], [], ['臺南']]
# - - -
# file: 224
# [['葡萄'], ['葉螨'], ['畢芬寧', '合賽芬普寧', '依殺螨', '賽芬螨', '賜派芬'], ['臺中', '彰化']]
# - - -
# file: 218
# [['水稻'], ['葉稻熱病'], ['撲殺熱', '三賽唑', '亞賜圃', '嘉賜三賽唑', '加普胺', '護粒松'], ['臺中']]
# - - -
# file: 280
# [['水稻'], ['稻熱病', '穗稻熱病'], [], ['臺東']]
# - - -
# file: 531
# [['番茄'], ['晚疫病'], ['凡殺克絕', '賽座滅', '亞托敏', '達滅芬', '錳乃浦', '甲基鋅乃浦', '免得爛', '鋅錳乃浦', '四氯異苯腈', '鋅錳克絕', '鋅錳右滅達樂'], []]
# - - -
# file: 519
# [['水稻'], ['瘤野螟'], ['賽洛寧', '得芬諾', '矽護芬'], ['彰化', '南投']]
# - - -
# file: 1099
# [[], ['稻熱病', '葉稻熱病'], ['撲殺熱', '亞賜圃', '嘉賜三賽唑', '加普胺', '護粒松', '微生物製劑', '亞磷酸'], ['花蓮']]
# - - -
# file: 1270
# [['香蕉'], ['黑星病', '葉斑病'], ['凡殺護矽得', '亞托敏'], []]
# - - -
# file: 1264
# [['香蕉', '雜草'], ['花薊馬', '水銹斑'], ['第滅寧', '陶斯松', '福瑞松'], []]
# - - -
# file: 900
# [['水稻'], ['水稻水象鼻蟲'], ['免扶克', '培丹', '加保扶', '丁基加保扶'], ['桃園']]
# - - -
# file: 914
# [['水稻', '雜草'], ['水稻水象鼻蟲'], ['培丹', '免扶克', '加保扶', '丁基加保扶'], ['臺北']]
# - - -
# file: 1258
# [['葉菜類', '落花生', '田菁', '毛豆', '大蒜', '青蔥', '甘藷', '綠肥作物'], ['斜紋夜蛾', '斑螟蛾'], ['性費洛蒙'], ['雲林', '臺南']]
# - - -
# file: 848
# [['果樹', '番石榴', '蓮霧', '文旦'], ['東方果實蠅', '果實蠅'], ['含毒甲基丁香油', '福木松', '蛋白質水解物', '芬殺松', '納乃得'], ['花蓮', '宜蘭']]
# - - -
# file: 860
# [['青蔥', '韭菜', '玉米', '茭白筍', '葡萄'], ['銹病'], ['三泰隆'], ['花蓮']]
# - - -
# file: 135
# [['芒果'], ['黑斑病', '果斑病'], ['維利黴素', '嘉賜銅', '歐索林酸', '嘉賜快得寧', '硫酸銅', '護粒丹', '氫氧化銅'], ['高雄', '屏東']]
# - - -
# file: 492
# [['水稻', '雜草'], ['水稻水象鼻蟲', '象鼻蟲'], ['培丹', '免扶克', '加保扶', '丁基加保扶'], ['苗栗']]
# - - -
# file: 486
# [['水稻'], ['飛蝨類', '白背飛蝨', '斑飛蝨', '褐飛蝨', '煤煙病', '草狀矮化病', '皺縮矮化病', '水稻縞葉枯病'], ['加保扶', '益達胺', '布芬第滅寧', '可尼丁'], ['苗栗']]
# - - -
# file: 1112
# [['荔枝'], ['露疫病'], ['福賽快得寧', '嘉賜貝芬', '鋅錳克絕', '快得寧', '鋅錳乃浦'], ['彰化', '南投']]
# - - -
# file: 323
# [['水稻'], ['葉稻熱病', '稻熱病', '二化螟'], ['撲殺熱', '三賽唑', '護粒松', '喜樂克拉', '亞賜圃', '加普胺', '嘉賜三賽唑', '培丹', '芬普尼', '撲滅松', '陶斯松'], ['臺南']]
# - - -
# file: 479
# [['水稻', '雜草'], ['瘤野螟', '紋枯病'], ['矽護芬', '布得芬諾', '培丹', '待克利', '賓克隆', '福多寧'], ['苗栗']]
# - - -
# file: 322
# [['芒果', '果樹'], ['炭疽病', '白粉病'], ['扶吉胺', '克熱淨', '免得爛', '三氟敏', '賽普護汰寧', '克收欣', '亞托敏', '貝芬撲克拉', '待克利', '腐絕快得寧', '腈硫醌', '甲基鋅乃浦', '撲克拉錳', '甲基多保淨', '錳乃浦', '鋅錳乃浦', '撲克拉', '賽普待克利', '貝芬依滅列', '免賴得', '菲克利腐絕', '鋅錳邁克尼', '快得保淨', '芬瑞莫', '無水硫酸銅'], ['臺南']]
# - - -
# file: 444
# [['洋香瓜', '瓜類'], ['露菌病', '白粉病'], ['克收欣', '賽普洛', '得克利', '百克敏', '賽座滅', '凡殺克絕'], ['宜蘭', '花蓮', '臺南']]
# - - -
# file: 336
# [['木瓜'], ['疫病', '炭疽病', '果疫病'], ['達滅芬', '亞托敏', '賽座滅', '嘉賜銅', '白列克敏', '賽普護汰寧', '福賽快得寧', '甲基鋅乃浦'], ['臺南']]
# - - -
# file: 487
# [['水稻'], ['二化螟', '螟蛾'], ['培丹', '芬普尼', '撲滅松', '賽達松', '加保扶'], ['苗栗']]
# - - -
# file: 1107
# [['芋頭'], ['疫病'], ['亞磷酸', '達滅芬', '嘉賜銅', '硫酸銅'], ['花蓮']]
# - - -
# file: 120
# [['水稻'], ['瘤野螟', '白葉枯病'], [], ['高雄']]
# - - -
# file: 849
# [['水稻', '蔬菜', '玉米', '落花生', '果樹', '柑桔'], ['軟腐病', '疫病', '炭疽病', '斜紋夜蛾', '潰瘍病', '白葉枯病'], [], ['花蓮']]
# - - -
# file: 1259
# [['荔枝', '龍眼', '無患子科'], ['荔枝椿象'], [], ['雲林', '臺南']]
# - - -
# file: 256
# [['番茄', '百香果'], ['疫病'], ['凡殺克絕', '亞托敏'], ['臺中']]
# - - -
# file: 1065
# [['水稻'], ['葉稻熱病', '稻熱病'], ['矽酸爐渣', '撲殺熱', '加普胺', '保米賜圃', '護粒松'], ['南投', '彰化']]
# - - -
# file: 1071
# [['葡萄'], ['葉螨'], ['畢芬寧', '依殺螨', '賽芬螨', '賜派芬', '芬殺螨', '阿巴汀'], ['臺中', '彰化']]
# - - -
# file: 1059
# [['蕉農'], [], ['鋅錳乃浦', '普克利'], []]
# - - -
# file: 240
# [['荔枝', '龍眼', '無患子科'], ['荔枝椿象'], ['陶斯松', '賽洛寧'], ['臺中']]
# - - -
# file: 687
# [['柑桔', '柑橘', '果樹'], ['黑星病', '黑點病', '潰瘍病', '褐腐病', '瘡痂病'], ['免得爛', '快得寧', '甲基多保淨', '扶吉胺', '易胺座', '亞托敏', '免賴得', '夏油', '香蕉用礦物油', '鋅錳乃浦', '腈硫醌', '四氯異苯腈', '波爾多', '波爾多液', '氧化亞銅', '嘉賜銅', '鋅錳滅達樂', '貝芬硫醌', '亞磷酸'], []]
# - - -
# file: 23
# [['水稻'], ['葉稻熱病', '穗稻熱病', '白葉枯病'], ['甲基多保淨', '嘉賜三賽唑', '護粒三賽唑', '保米熱斯', '三賽唑', '加普胺', '撲殺熱', '鋅錳乃浦', '克枯爛', '鏈四環黴素'], ['苗栗']]
# - - -
# file: 863
# [['水稻'], ['稻熱病'], ['富米熱斯', '熱必斯', '保米熱斯', '三賽唑', '嘉賜三賽唑', '護粒丹', '亞賜圃', '保米賜圃', '保米黴素', '加普胺', '撲殺熱'], ['花蓮']]
# - - -
# file: 877
# [['水稻'], ['褐飛蝨', '煤煙病', '葉蟬'], ['丁基加保扶', '安丹', '滅必蝨', '丁基滅必蝨', '加保利', '毆殺松', '印楝素'], ['花蓮']]
# - - -
# file: 888
# [['水稻'], ['稻熱病'], ['富米熱斯', '熱必斯', '三賽唑', '嘉賜三賽唑', '護粒丹', '保米賜圃', '加普胺', '撲殺熱'], ['花蓮']]
# - - -
# file: 650
# [['馬鈴薯', '番茄'], ['晚疫病'], ['亞托敏', '達滅芬', '波爾多液', '氫氧化銅', '四氯異苯腈', '免得爛', '鋅錳乃浦', '鋅錳克絕', '滅達樂'], []]
# - - -
# file: 136
# [['果樹', '花木', '荔枝', '龍眼', '蓮霧', '番石榴', '景觀樹木', '觀賞植物'], ['咖啡木蠹蛾', '蛾類', '台灣黃毒蛾', '小白紋毒蛾'], ['賽洛寧', '第滅寧'], ['高雄']]
# - - -
# file: 1139
# [['木瓜', '番石榴', '荔枝', '紅龍果', '豆菜類', '柑桔', '芒果'], ['疫病', '根腐病', '炭疽病', '露疫病', '酸腐病', '褐腐病', '潰瘍病', '黑星病', '瘡痂病'], ['亞磷酸', '硫酸銅'], ['高雄']]
# - - -
# file: 320
# [['芒果', '果樹'], ['炭疽病', '白粉病'], ['扶吉胺', '克熱淨', '免得爛', '三氟敏', '賽普護汰寧', '克收欣', '亞托敏', '貝芬撲克拉', '待克利', '腐絕快得寧', '腈硫醌', '甲基鋅乃浦', '撲克拉錳', '甲基多保淨', '錳乃浦', '鋅錳乃浦', '撲克拉', '賽普待克利', '貝芬依滅列', '免賴得', '菲克利腐絕', '鋅錳邁克尼', '快得保淨', '芬瑞莫', '無水硫酸銅'], ['臺南']]
# - - -
# file: 308
# [['水稻'], ['稻熱病', '穗稻熱病'], ['撲殺熱', '護粒松', '喜樂克拉', '三賽唑'], ['臺東']]
# - - -
# file: 1138
# [['水稻'], ['穗稻熱病', '稻熱病'], ['護粒三賽唑', '亞賜圃', '嘉賜黴素'], ['高雄']]
# - - -
# file: 1104
# [['水稻'], ['白葉枯病'], ['撲殺熱', '鏈四環黴素', '克枯爛'], ['彰化', '南投']]
# - - -
# file: 1110
# [['水稻'], ['穗稻熱病', '葉稻熱病', '稻熱病', '紋枯病'], ['三賽唑', '護粒松', '加普胺', '嘉賜三賽唑', '克熱賜圃', '富米熱斯', '亞賜圃', '賓克隆', '福多寧', '維利黴素', '菲克利'], ['彰化', '南投']]
# - - -
# file: 36
# [['水稻'], ['葉稻熱病'], ['甲基多保淨', '嘉賜三賽唑', '護粒三賽唑', '保米熱斯', '三賽唑', '加普胺', '撲殺培丹'], ['苗栗']]
# - - -
# file: 22
# [['果樹'], ['東方果實蠅'], ['含毒甲基丁香油', '賜諾殺', '酵母球'], ['花蓮']]
# - - -
# file: 686
# [['果樹', '芒果', '荔枝', '龍眼', '番石榴', '楊桃'], ['東方果實蠅', '果實蠅'], ['含毒甲基丁香油', '蛋白質水解物', '馬拉松', '芬殺松', '賜諾殺'], []]
# - - -
# file: 1312
# [['蕉農'], ['黑星病', '葉斑病'], ['鋅錳乃浦', '普克利', '凡殺護矽得', '亞托敏'], []]
# - - -
# file: 719
# [['葉菜類', '茼蒿', '落花生', '田菁', '毛豆', '豌豆', '大蒜', '青蔥', '甘藷', '玉米', '蓮花', '花卉'], ['斜紋夜蛾', '斑螟蛾'], ['性費洛蒙', '蘇力菌'], []]
# - - -
# file: 902
# [['蓮花', '田菁', '雜草', '綠肥作物'], ['斜紋夜蛾', '小黃薊馬'], ['性費洛蒙', '芬普尼', '亞滅培', '益達胺', '蘇力菌'], ['臺北']]
# - - -
# file: 1272
# [['香蕉', '雜草'], ['水銹斑', '花薊馬'], ['第滅寧', '陶斯松', '福瑞松'], []]
# - - -
# file: 1266
# [['蕉農'], [], [], []]
# - - -
# file: 241
# [['葡萄'], ['葉螨'], ['畢芬寧', '依殺螨', '賽芬螨', '賜派芬', '芬殺螨'], ['臺中', '彰化']]
# - - -
# file: 255
# [['葡萄', '花生'], ['晚腐病'], ['得克利'], ['臺中']]
# - - -
# file: 1058
# [['香蕉', '豆科', '茄科', '雜草'], ['嵌紋病', '萎縮病', '蚜蟲', '棉蚜', '蕉蚜'], ['加保扶'], []]
# - - -
# file: 251
# [['葡萄', '花生'], ['晚腐病'], ['得克利'], ['臺中']]
# - - -
# file: 537
# [['檸檬', '柳丁', '柑桔', '雜草', '柑橘'], ['潰瘍病'], ['維利黴素', '波爾多', '氧化亞銅', '嘉賜銅'], ['臺中', '南投', '彰化']]
# - - -
# file: 523
# [['荔枝'], ['荔枝癭蚋', '炭疽病'], [], ['南投', '彰化']]
# - - -
# file: 912
# [['葉菜類', '草莓', '花卉', '草花類', '盆花類'], ['露菌病', '菌核病', '灰黴病'], [], []]
# - - -
# file: 1262
# [['香蕉', '豆科', '茄科', '雜草'], ['蚜蟲', '嵌紋病', '萎縮病'], ['加保扶'], []]
# - - -
# file: 735
# [['洋香瓜'], ['蚜蟲', '薊馬', '銀葉粉蝨', '南瓜捲葉病毒'], [], ['臺南']]
# - - -
# file: 721
# [['洋香瓜', '南瓜'], ['黑點根腐病'], ['脫克松'], ['臺南']]
# - - -
# file: 696
# [['柑橘', '果樹'], ['褐腐病'], ['鋅錳滅達樂', '鋅錳乃浦', '貝芬硫醌', '亞磷酸'], ['臺南']]
# - - -
# file: 641
# [['文旦', '白柚'], ['柑橘窄胸天牛'], ['賽洛寧', '陶斯松', '加保利', '白殭菌', '依殺螨', '密滅汀', '芬普毆螨多', '克芬螨', '芬普螨', '汰芬隆', '阿巴汀'], []]
# - - -
# file: 127
# [['水稻'], ['穗稻熱病', '稻熱病'], ['三賽唑', '富米熱斯', '嘉賜三賽唑', '亞賜圃'], ['高雄']]
# - - -
# file: 1100
# [['玉米'], ['煤紋病'], [], ['花蓮']]
# - - -
# file: 318
# [['番荔枝', '釋迦', '雜草'], ['薊馬', '小黃薊馬', '花薊馬'], ['畢芬寧', '益達胺', '賽洛寧', '賜諾特', '第滅達胺', '硫敵克'], ['臺東']]
# - - -
# file: 495
# [['水稻'], ['飛蝨類', '白背飛蝨', '斑飛蝨', '褐飛蝨', '煤煙病', '草狀矮化病', '皺縮矮化病', '水稻縞葉枯病'], ['加保扶', '益達胺', '布芬第滅寧', '可尼丁'], ['苗栗']]
# - - -
# file: 1101
# [['荔枝', '龍眼', '楊桃', '蓮霧', '番石榴'], ['黑角舞蛾'], ['賽洛寧', '第滅寧', '芬化利'], ['彰化', '南投']]
# - - -
# file: 1115
# [['水稻'], ['褐飛蝨', '白葉枯病'], ['賽速安', '可尼丁', '益達胺', '派滅淨', '鏈四環黴素', '克枯爛'], ['彰化']]
# - - -
# file: 481
# [['芋頭', '蔬菜', '花卉', '雜糧', '綠肥作物', '果樹'], ['斜紋夜蛾'], ['性費洛蒙'], ['苗栗']]
# - - -
# file: 683
# [['文旦', '白柚'], ['柑橘窄胸天牛'], ['賽洛寧', '陶斯松', '加保利'], []]
# - - -
# file: 33
# [['水稻'], ['白葉枯病'], ['克枯爛', '嘉賜克枯爛', '鏈四環黴素', '克枯三賽唑', '撲殺熱'], ['苗栗']]
# - - -
# file: 720
# [['洋香瓜'], ['薊馬', '銀葉粉蝨', '蚜蟲'], ['克凡派', '達特南', '益達胺', '第滅寧'], ['臺南']]
# - - -
# file: 708
# [['芒果', '文旦'], ['小黃薊馬', '薊馬'], ['丁基加保扶', '益達胺', '賽洛寧', '可尼丁', '亞滅培', '賽速安'], ['臺南']]
# - - -
# file: 907
# [['蓮花', '田菁', '雜草', '綠肥作物'], ['小黃薊馬', '斜紋夜蛾'], ['益達胺', '芬普尼', '亞滅培', '性費洛蒙', '蘇力菌'], ['臺北']]
# - - -
# file: 536
# [['水稻'], ['葉稻熱病'], ['撲殺熱', '三賽唑', '亞賜圃', '嘉賜三賽唑', '加普胺', '護粒松'], ['臺中', '彰化']]
# - - -
# file: 278
# [['釋迦', '番荔枝', '果樹', '雜草'], ['小黃薊馬', '葉螨', '薊馬'], ['密滅汀', '馬拉松', '芬普寧', '畢達本', '畢芬寧', '益達胺', '賽洛寧', '硫敵克'], ['臺東']]
# - - -
# file: 1077
# [['水稻'], ['葉稻熱病', '稻熱病'], ['三賽唑', '喜樂克拉', '丙基喜樂松', '護粒松', '芬諾尼'], ['臺南', '嘉義']]
# - - -
# file: 291
# [['番荔枝', '金針', '洛神葵', '水稻', '雜草', '果樹', '鳳梨釋迦', '文旦柚', '紅龍果', '酪梨', '高接梨', '鳳梨', '番石榴', '蔬菜', '雜糧', '特作', '樹豆', '杭菊', '荖葉'], ['炭疽病', '潰瘍病', '萎凋病'], [], ['臺東']]
# - - -
# file: 246
# [['水稻'], ['葉稻熱病'], ['撲殺熱', '三賽唑', '亞賜圃', '嘉賜三賽唑', '護粒松', '芬諾尼'], ['臺中', '彰化', '南投']]
# - - -
# file: 520
# [['水稻'], ['白葉枯病', '紋枯病'], ['鏈四環黴素', '克枯爛', '賓克隆', '福多寧', '維利黴素', '菲克利'], ['彰化', '南投']]
# - - -
# file: 252
# [['荔枝', '龍眼', '欒樹'], ['荔枝椿象'], ['賽洛寧', '亞滅培'], ['臺中']]
# - - -
# file: 1275
# [['香蕉', '雜草'], ['花薊馬', '水銹斑'], ['第滅寧', '陶斯松', '福瑞松'], []]
# - - -
# file: 736
# [['水稻'], ['白葉枯病'], ['鏈四環黴素', '撲殺熱', '克枯爛'], ['臺南']]
# - - -
# file: 871
# [['水稻'], ['穗稻熱病', '稻熱病', '葉稻熱病'], ['保米熱斯', '富米熱斯', '維利熱必斯', '保米黴素', '嘉賜黴素'], ['花蓮']]
# - - -
# file: 118
# [['檬果'], ['炭疽病', '白粉病', '小黃薊馬', '薊馬'], ['貝芬依滅列', '布瑞莫', '免賴得', '克收欣', '賽普待克利', '克熱淨'], ['高雄']]
# - - -
# file: 483
# [['水稻'], ['稻熱病', '葉稻熱病'], ['撲殺熱', '嘉賜三賽唑', '護粒三賽唑', '保米熱斯', '三賽唑', '加普胺'], ['苗栗']]
# - - -
# file: 1117
# [['水稻'], ['葉稻熱病', '稻熱病'], ['撲殺熱', '三賽唑', '嘉賜三賽唑', '加普胺', '護粒松', '矽酸爐渣'], ['南投', '彰化']]
# - - -
# file: 468
# [['水稻'], ['稻熱病', '葉稻熱病'], ['撲殺熱', '嘉賜三賽唑', '護粒三賽唑', '保米熱斯', '三賽唑', '加普胺'], ['苗栗']]
# - - -
# file: 332
# [['水稻'], ['穗稻熱病', '稻熱病'], ['芬諾尼', '嘉賜三賽唑', '保米熱斯', '喜樂克拉', '加普胺', '克熱淨', '護粒丹'], ['臺南']]
# - - -
# file: 327
# [['水稻'], ['螟蟲', '穗稻熱病'], [], ['臺南']]
# - - -
# file: 455
# [[], [], ['可尼丁', '賽速安', '派滅淨', '陶毆松', '滅必蝨', '益達胺', '加保扶', '印楝素'], ['花蓮']]
# - - -
# file: 496
# [['水稻'], ['二化螟', '三化螟', '螟蛾'], ['培丹', '芬普尼', '撲滅松', '賽達松', '加保扶', '芬殺松', '益滅松'], ['苗栗']]
# - - -
# file: 1102
# [[], ['葉稻熱病', '稻熱病'], ['矽酸爐渣', '加普胺', '保米賜圃', '護粒松'], ['南投', '彰化']]
# - - -
# file: 657
# [['文旦', '白柚', '椪柑', '柳丁', '茂谷柑', '柑橘'], ['薊馬', '潛葉蛾', '小黃薊馬', '花薊馬'], ['丁基加保扶', '芬諾克', '陶斯松', '佈飛賽滅寧'], []]
# - - -
# file: 18
# [['水稻'], ['葉稻熱病', '穗稻熱病'], ['撲殺熱', '三賽唑', '亞賜圃', '丙基喜樂松', '護粒松', '富米熱斯', '嘉賜黴素', '護粒三賽唑'], ['花蓮']]
# - - -
# file: 1314
# [['蕉農'], ['象鼻蟲', '假莖象鼻蟲', '球莖象鼻蟲'], ['凡殺護矽得', '加保扶'], []]
# - - -
# file: 737
# [[], ['褐腐病', '潰瘍病'], ['硫酸銅', '福賽得', '鋅錳滅達樂', '鋅錳乃浦', '貝芬硫醌', '波爾多', '波爾多液', '氧化亞銅', '嘉賜銅'], ['臺南']]
# - - -
# file: 1260
# [['紅龍果'], ['潰瘍病'], [], ['雲林', '臺南']]
# - - -
# file: 1248
# [['香蕉', '豆科', '茄科', '雜草'], ['嵌紋病', '蚜蟲'], ['加保扶'], []]
# - - -
# file: 253
# [['梨', '龍柏'], ['赤星病'], ['滅普寧', '得克利', '富爾邦', '芬瑞莫', '三泰芬', '比多農', '三氟敏', '克熱淨'], ['臺中']]
# - - -
# file: 509
# [['落花生', '甘藷', '黑豆', '雜糧', '玉米', '高粱', '薏苡', '水稻', '甘蔗', '牧草'], ['秋行軍蟲'], ['性費洛蒙'], ['苗栗']]
# - - -
# file: 284
# [['水稻'], ['稻熱病', '白葉枯病'], [], ['臺東']]
# - - -
# finish

# %%
file = open("train/dataTrainComplete/" + str(289) + ".txt", "r", encoding='utf-8-sig', errors='ignore')
sentances = file.readlines()
# print(sentances)
file.close()

text = ""
for item in sentances:
    replace = re.sub(r'[0-9]+|[%]|[-]','', item.replace("\x7f", ""))
    text += replace

jieba.analyse.set_stop_words('stop_words.txt')
tags = jieba.analyse.extract_tags(text, topK=20, withWeight=True)

words = pseg.cut(text)
keywords = [[] for i in range(4)]
key_index_list = ["crop", "pest", "chem", "city"]


# extract keywords in the given dictionaries
for word, flag in words:
    if flag in key_index_list:
        index = key_index_list.index(flag)
        if(word not in keywords[index]):
            keywords[index].append(word)
print(keywords)
words = pseg.cut(text)
print(text)
for word, flag in words:
    if(word not in stopwords):
        if(flag not in ["m", "p", "d", "c", "eng"]):
            print(word, flag)
# Out:
# [['水稻'], ['穗稻熱病', '稻熱病', '吊穗', '吊狗'], [], ['臺東']]
# 連日降雨且溫差大濕度高，請農友加強防範穗稻熱病，避免產量損失。
# 行政院農業委員會臺東區農業改良場（以下簡稱臺東場）表示，目前轄區水稻生長情形多已達孕穗期至抽穗期，惟近日受梅雨鋒面影響，連日有雨，氣溫落差大，為「穗稻熱病」好發時期。本病害對水稻產量影響甚劇，臺東場籲請農友務必做好防治工作，避免病害發生及蔓延。「穗稻熱病」主要發生於穗頸、枝梗、穀粒及護穎等部位，在水稻抽穗前，稻熱病孢子隨著雨水或露水飛落在劍葉葉舌及葉節上，抽穗時經過該部位即被孢子感染。罹病初期穗頸及枝梗上之患部呈暗褐色，病原菌侵入組織壞死以致養分不能向上輸送，影響整穗發育，並自罹病部位彎曲，俗稱「吊穗」或「吊狗」，若穀粒受感染，病斑則呈暗灰色，嚴重時穀粒無法充實或不稔，俗稱「空包彈」。若發生於穗頸未及時做好防治工作，對稻米產量影響最為嚴重，農友應特別注意防範。
# 本病害防治時機，應把握抽穗前及齊穗期進行穗稻熱病預防性施藥，建議於抽穗前~天完成施藥，若天氣不穩定或病害持續發生，於齊穗期再進行第二次施藥，以確保防治成效，施藥時應確實遵守植保手冊相關規定，尤其生育後期更應注意安全採收期等注意事項，藥劑種類請參考「農藥資訊服務網」（http://pesticide.baphiq.gov.tw）或「植物保護手冊」（http://www.tactri.gov.tw），或洽詢臺東場植物保護研究室（電話）。臺東場表示，去年因水稻抽穗後遇連日有雨，部分農友未及時做好預防工作，造成損失；今年抽穗後又遇梅雨，為避免疫情發生，務必請農友做好預防工作。另，農委會動植物防疫檢疫局亦於植物疫情管理資訊網(http://phis.baphiq.gov.tw/WebEvery.nsf/index)設置「稻熱病疫情現況」，提供民眾上網參考。
#
# 降雨 event
# 溫差 x
# 大濕度 n
# 高 a
# 請 zg
# 農友 x
# 防範 x
# 穗稻熱病 pest
# 產量 x
# 損失 x
#
#  x
# 行政院 n
# 農業 x
# 委員會 x
# 臺東區 x
# 農業 x
# 改良場 x
# 簡稱 x
# 臺東 city
# 場 zg
# 轄區 x
# 水稻 crop
# 生長 x
# 情形 n
# 達 v
# 孕穗期 t
# 抽穗期 event
# 惟 b
# 近日 t
# 受 v
# 梅雨 nr
# 鋒面 event
# 影響 x
# 雨 n
# 氣溫 x
# 落差 a
# 「 x
# 穗稻熱病 pest
# 發 v
# 時期 x
# 病害 n
# 水稻 crop
# 產量 x
# 影響 x
# 臺東 city
# 場 zg
# 籲請 x
# 農友 x
# 務必 x
# 做好 v
# 防治 v
# 工作 vn
# 病害 n
# 發生 x
# 蔓延 v
# 「 x
# 穗稻熱病 pest
# 發生 x
# 穗 n
# 頸 ng
# 枝梗 n
# 穀粒 x
# 護 v
# 穎 nr
# 部位 n
# 水稻 crop
# 抽穗 v
# 前 f
# 稻熱病 pest
# 孢子 n
# 雨水 n
# 露水 v
# 飛落 x
# 劍葉 x
# 葉舌 x
# 葉節 n
# 抽穗 v
# 時經 x
# 部位 n
# 孢子 n
# 感染 v
# 罹病 v
# 初期 t
# 穗 n
# 頸 ng
# 枝梗 n
# 患部 n
# 呈 v
# 暗褐色 n
# 病原菌 n
# 侵入 v
# 組織 x
# 壞死 x
# 養分 x
# 輸送 x
# 影響 x
# 整穗 n
# 發育 x
# 罹病 v
# 部位 n
# 彎曲 x
# 俗稱 x
# 「 x
# 吊穗 pest
# 「 x
# 吊狗 pest
# 穀粒 x
# 受 v
# 感染 v
# 病斑 n
# 呈 v
# 暗 v
# 灰色 n
# 時 zg
# 穀粒 x
# 充實 x
# 不稔 a
# 俗稱 x
# 「 x
# 空包彈 x
# 發生 x
# 穗 n
# 頸 ng
# 做好 v
# 防治 v
# 工作 vn
# 稻米 n
# 產量 x
# 影響 x
# 農友 x
# 應 x
# 特別注意 x
# 防範 x
#
#  x
# 病害 n
# 防治 v
# 時機 x
# 應 x
# 把握 v
# 抽穗 v
# 前 f
# 齊穗 nr
# 期 q
# 穗稻熱病 pest
# 預防性 x
# 施藥 x
# 建議 x
# 抽穗 v
# 前 f
# 天 q
# 施藥 x
# 天氣 x
# 穩定 x
# 病害 n
# 持續 x
# 發生 x
# 於齊穗 nr
# 期 q
# 施藥 x
# 確保 x
# 防治 v
# 成效 a
# 施藥 x
# 時應 n
# 確實 x
# 遵守 v
# 植保 nr
# 手冊 x
# 相關 x
# 生育 vn
# 後期 x
# 應 v
# 注意安全 nz
# 採收期 x
# 注意事項 x
# 藥劑 x
# 種類 x
# 請 zg
# 參考 x
# 「 x
# 農藥 x
# 資訊 x
# 服務網 x
# 「 x
# 植物保護 x
# 手冊 x
# 洽詢 x
# 臺東 city
# 場 zg
# 植物保護 x
# 研究室 n
# 電話 x
# 臺東 city
# 場 zg
# 去年 t
# 水稻 crop
# 抽穗 v
# 遇 v
# 雨 n
# 農友 x
# 做好 v
# 預防 x
# 工作 vn
# 損失 x
# 抽穗 v
# 遇 v
# 梅雨 nr
# 疫情 n
# 發生 x
# 務必 x
# 請 zg
# 農友 x
# 做好 v
# 預防 x
# 工作 vn
# 農委會 x
# 動植物 x
# 防疫 vn
# 檢疫局 x
# 植物 n
# 疫情 n
# 管理 vn
# 資訊網 x
# 設置 x
# 「 x
# 稻熱病 pest
# 疫情 n
# 現況 x
# 提供 v
# 民眾 n
# 上網 x
# 參考 x
#
#  x

# %% [markdown]
# ### 檢視結果
# 對每個檔案查看斷詞結果的前五個字詞

# %%
currentFolder = "train"

# %%
def display_file(path):
    file = open(path, "r")
    print(file.readlines()[0].split(" ")[:5])
    file.close()

# %%
path = f"{currentFolder}/ArticleSegment"
files = listdir(mypath)

for f in files:
    fullpath = join(mypath, f)
    if isfile(fullpath):
        fileNum = f.split(".")[0]
        if(len(fileNum) == 0):
            continue
        print(fileNum, end=": ") 
        display_file(f"{currentFolder}/ArticleSegment/{fileNum}.txt")
# Out:
# 289: ['降雨', '溫差', '大濕度', '農友', '防範']
# 504: ['危害', '多種', '作物', '木瓜', '秀粉介殼蟲']
# 262: ['關心', '肺炎', '疫情', '留心', '西瓜']
# 276: ['臺東', '地區', '水稻', '瘤野螟', '縱捲葉蟲']
# 510: ['苗栗', '水稻', '發白', '葉枯病', '籲請']
# 921: ['發佈', '水稻', '葉稻熱病', '疫情', '警報']
# 1292: ['冬末', '初春', '種植', '香蕉', '組培']
# 29: ['發布', '水稻', '葉稻熱病', '防治', '警報']
# 1331: ['水稻', '飛蝨類', '害蟲', '密度', '攀升']
# 1319: ['蕉農', '務必', '採行', '正確', '香蕉葉']
# 841: ['寒流', '到來', '各類', '作物', '作好']
# 672: ['紫斑病', '薊馬', '危害', '日益嚴重', '台南']
# 1127: ['中部', '地區', '一期稻作', '葉稻熱病', '發生']
# 1133: ['氣候', '多變', '溫差', '籲請', '農友']
# 470: ['發佈', '穗稻熱病', '白葉枯病', '警報', '警報']
# 458: ['水稻', '稻熱病', '發生', '花蓮', '農業']
# 303: ['巨爵', '颱風', '影響', '近日', '風雨']
# 465: ['梨木蝨', '危害', '籲請', '防治', '苗栗縣']
# 471: ['氣候', '高溫', '乾燥', '苗栗', '改場']
# 1132: ['天氣', '變化', '花蓮', '籲請', '農友']
# 1126: ['氣候', '多變', '溫差', '臺南', '農業']
# 129: ['豪雨', '水稻', '白葉枯病', '發生', '農友']
# 897: ['近期', '果實蠅', '密度', '農友', '果實蠅']
# 667: ['檬果', '栽培', '薊馬', '密度', '農友']
# 673: ['柑橘類', '陸續', '開花期', '農友', '蚜蟲']
# 698: ['田園', '管理', '起工', '柑橘類', '採收']
# 14: ['花蓮', '地區', '發布', '水稻', '穗稻熱病']
# 868: ['花蓮', '作物', '病蟲害', '疫情', '警報']
# 1324: ['儘速', '宣導', '單位', '轄區', '蕉農']
# 713: ['過後', '台南', '提醒', '農友', '預防']
# 1278: ['籲請', '蕉農', '冬春', '期間', '確實']
# 1244: ['種植', '香蕉', '組織培養', '苗者', '務必']
# 1250: ['宣導', '蕉農', '雨季', '期間', '香蕉葉']
# 511: ['荔枝椿象', '蠢蠢欲動', '籲請', '農友', '配合']
# 505: ['水稻', '白葉枯病', '紋枯病', '瘤野螟', '部份']
# 263: ['水稻', '陸續', '抽穗期', '籲請', '農民']
# 1052: ['芒果', '開花期', '台南', '改場', '防治']
# 1087: ['田間', '番茄潛旋蛾', '數量', '籲請', '農友']
# 261: ['中部', '地區', '氣候', '條件', '適合']
# 1093: ['番茄', '晚疫病', '發生', '中場', '籲請']
# 936: ['發佈', '轄區', '稻縱捲葉蟲', '疫情', '警報']
# 711: ['南部', '連續', '下雨', '台南', '提醒']
# 1332: ['秋冬季', '蔬果', '生產', '盛期', '呼籲']
# 1326: ['蕉株', '抽穗', '期間', '籲請', '蕉農']
# 856: ['草莓', '殺手', '灰黴病', '菌核病', '防治']
# 103: ['桃園市', '新竹縣', '鄉鎮', '發生', '葉稻熱病']
# 665: ['蓮花', '小黃薊馬', '族群', '密度', '增高']
# 117: ['小果番茄', '炭疽病', '發生', '高雄', '呼籲']
# 659: ['薊馬', '密度', '極易', '果實', '危害']
# 1130: ['天氣', '變化', '花蓮', '改場', '提醒']
# 498: ['苗栗', '改良場', '發佈', '水稻', '白葉枯病']
# 1118: ['為害', '果樹', '黑角舞蛾', '幼蟲', '中部']
# 301: ['番荔枝', '小黃薊馬', '東方果實蠅', '密度', '升高']
# 329: ['梅雨季', '將來', '南區', '改場', '提醒']
# 472: ['流來', '苗栗', '農業', '改良場', '呼籲']
# 300: ['天鵝', '進逼', '提醒', '農友', '做好']
# 1119: ['台中區', '農業', '改良場', '籲請', '農民']
# 1125: ['中部', '地區', '黑角舞蛾', '發生', '警報']
# 670: ['時值', '釋迦', '果實', '生長期', '氣候']
# 857: ['赤星病', '梨木蝨', '防治', '技術', '座談會']
# 1327: ['冬季', '氣候', '溫暖', '乾燥', '適合']
# 1333: ['冬末', '初春時節', '香蕉', '組織培養', '苗易']
# 704: ['芒果', '陸續', '開花期', '台南', '籲請']
# 1290: ['香蕉葉', '病害', '影響', '抽穗', '飽熟']
# 923: ['防範', '花薊馬', '斜紋夜盜蟲', '疫情', '桃園']
# 1253: ['提醒', '宣導', '單位', '轄區', '蕉農']
# 1247: ['蕉株', '抽穗', '期間', '務必', '宣導']
# 248: ['葡萄', '套袋', '晚腐', '不來', '籲請']
# 1086: ['田間', '監測', '發現', '葉稻熱病', '病斑']
# 1041: ['籲請', '農友', '防治', '穗稻熱病', '臺南市']
# 1082: ['本縣', '瓜實蠅', '甜菜夜蛾', '田間', '密度']
# 516: ['荔枝椿象', '籲請', '農友', '配合', '藥劑']
# 933: ['發佈', '水稻', '紋枯病', '警報', '水稻']
# 1243: ['宣導', '蕉農', '香蕉', '黑星病', '防治']
# 1280: ['香蕉', '籲請', '組織培養', '種植者', '香蕉']
# 700: ['踴躍', '參加', '洋香瓜', '病毒', '病防治']
# 847: ['文旦', '象鼻蟲', '密度', '增高', '農友']
# 853: ['花蓮', '宜蘭', '地區', '作物', '病蟲害']
# 1337: ['蕉農', '儘速', '做好', '颱風', '蕉園']
# 1323: ['夏秋', '季節', '期間', '籲請', '蕉農']
# 476: ['水稻', '白葉枯病', '警報', '病蟲害', '水稻']
# 310: ['天晴', '農友', '鳳梨釋迦', '病害', '防治']
# 311: ['鳳梨釋迦', '果園', '銹病', '零星', '發生']
# 305: ['天氣', '陰晴不定', '農友', '稻熱病', '防治']
# 463: ['穗稻熱病', '影響', '水稻', '產量', '花蓮']
# 1120: ['二期稻作', '白葉枯病', '發生', '警報', '韋帕']
# 113: ['水稻', '害蟲', '密度', '升高', '高雄']
# 675: ['檬果', '開花期', '台南', '籲請', '果農']
# 661: ['柑桔窄胸天牛', '羽化', '台南', '籲請', '農友']
# 107: ['瓜實蠅', '密度', '升高', '高雄', '瓜農']
# 649: ['斜紋夜盜蟲', '密度', '升高', '確保', '作物']
# 891: ['花蓮', '宜蘭', '地區', '作物', '病蟲害']
# 885: ['植物', '生鏽', '青蔥', '銹病', '發生']
# 12: ['花蓮', '地區', '發布', '水稻', '葉稻熱病']
# 846: ['花蓮', '宜蘭', '地區', '作物', '病蟲害']
# 701: ['天氣', '冷涼', '台南', '改場', '呼籲']
# 1256: ['洋香瓜', '小型', '害蟲', '密度', '攀升']
# 1054: ['苗栗', '地區', '發布', '水稻水象鼻蟲', '螟蟲']
# 1068: ['八卦', '山脈', '地區', '黑角舞蛾', '發生']
# 298: ['番荔枝', '害蟲', '密度', '升高', '籲請']
# 1056: ['時值', '檬果', '盛花期', '高雄', '籲請']
# 529: ['二期稻作', '瘤野螟', '紋枯病', '發生', '警報']
# 267: ['梅雨', '鋒面', '葡萄', '果農', '晚腐病']
# 501: ['梅雨季', '苗栗', '籲請', '農民', '提早']
# 273: ['臺東', '局部地區', '釋迦', '害蟲', '密度']
# 924: ['二期', '水稻', '陸續', '插秧', '請留']
# 918: ['稻飛蝨', '已現', '縱捲葉蟲', '疫情', '持續']
# 10: ['天氣', '多變', '溫差', '山區', '偏施']
# 850: ['花蓮', '宜蘭', '地區', '作物', '病蟲害']
# 1320: ['抽穗期', '蕉區', '適逢', '香蕉', '花薊馬']
# 1334: ['適逢', '初春', '氣候', '乾燥', '蕉苗易']
# 878: ['作物', '病蟲害', '診斷', '服務站', '農民']
# 893: ['稻熱病', '零星', '發生', '屏東縣', '政府']
# 887: ['花蓮', '宜蘭', '地區', '月份', '作物']
# 105: ['稻熱病', '蠢蠢欲動', '高雄', '籲請', '農友']
# 663: ['連續', '大雨', '台南', '改場', '提醒']
# 449: ['零星', '地區', '稻熱病', '嚴重危害', '農友']
# 313: ['秋行軍蟲', '持續', '臺東區', '改場', '提醒']
# 475: ['水稻', '葉稻熱病', '防治', '地點', '時期']
# 307: ['風雨', '過後', '農友', '防治', '柑橘']
# 306: ['颱風', '過後', '農友', '防治', '穗稻熱病']
# 474: ['中國', '梨木蝨', '危害', '改場', '籲請']
# 104: ['本場', '發布', '水稻', '葉稻熱病', '預警']
# 662: ['東方果實蠅', '密度', '持續上升', '南區', '農業']
# 676: ['一期稻作', '分蘗期', '農友', '葉稻熱病', '二化螟']
# 110: ['雨季', '高雄', '籲請', '農友', '防範']
# 138: ['籲請', '農友', '防範', '浮現', '病害']
# 892: ['果實蠅', '密度', '屏東縣', '政府', '籲請']
# 879: ['颱風', '過境', '西瓜', '罹患', '細菌性']
# 39: ['苗栗', '改場', '發佈', '水稻', '穗稻熱病']
# 845: ['文旦', '提早', '開花', '柑桔', '薊馬']
# 851: ['龍王', '颱風', '籲請', '農民', '農作物']
# 689: ['南區', '改場', '籲請', '農民', '防治']
# 1282: ['香蕉', '籲請', '蕉農', '梅雨季節', '期間']
# 716: ['秋天', '咖啡', '銹病', '季節', '南區']
# 1255: ['蕉農', '抽穗', '蕉株', '花薊馬', '防治']
# 919: ['發佈', '新竹', '地區', '東方果實蠅', '發生']
# 925: ['水稻', '二化螟', '疫情', '發生', '桃園']
# 299: ['蓮花', '颱風', '接近', '影響', '籲請']
# 598: ['低氣壓', '過境', '氣候', '陰晴不定', '台東']
# 201: ['甜柿', '白粉病', '角斑病', '中部', '地區']
# 215: ['臺中', '改場', '彰化', '地區', '褐飛蝨']
# 1232: ['籲請', '蕉農', '香蕉葉', '黑星病', '防治']
# 1226: ['氣候', '回暖', '蕉株', '生育', '旺盛']
# 956: ['蘇鐵', '白輪盾介殼蟲', '防治', '宣導', '摺頁']
# 771: ['流來', '台南', '改場', '設施', '番茄']
# 759: ['大雨', '南區', '改場', '水稻', '白葉枯病']
# 1352: ['初春', '時期', '氣候', '乾燥', '香蕉']
# 836: ['花蓮', '局部地區', '稻熱病', '發生', '農友']
# 188: ['花蓮', '水稻', '陸續', '分蘗', '抽穗期']
# 89: ['桃園', '新竹', '地區', '水稻', '瘤野螟']
# 611: ['新聞稿', '檬果', '開花', '季節', '台南']
# 163: ['降雨', '頻繁', '高雄', '籲請', '農友']
# 1391: ['日夜', '溫差', '變化', '高雄', '農業']
# 1178: ['發佈', '年期', '區葉', '病害', '防治']
# 375: ['水稻', '白葉枯病', '發生', '風險', '提高']
# 1187: ['發佈', '年期', '區葉', '病害', '防治']
# 1193: ['宣導', '蕉農', '抽穗', '蕉株', '花薊馬']
# 361: ['臺南', '近日', '低溫', '濕冷', '馬鈴薯']
# 1186: ['宣導', '貴屬', '蕉農', '抽穗', '蕉株']
# 412: ['柑橘窄胸天牛', '羽化', '臺南', '改場', '籲請']
# 1151: ['荔枝', '高雄', '籲請', '農民', '蛾類']
# 1390: ['豪雨', '過後', '蔬菜', '病害', '蠢蠢欲動']
# 610: ['發佈', '新聞稿', '提醒', '農民', '防治']
# 88: ['水稻', '抽穗期', '部份', '田區', '零星']
# 176: ['赤星病', '感染', '龍柏', '農友', '管理']
# 823: ['花蓮', '作物', '病蟲害', '疫情', '警報']
# 77: ['柑桔', '枯黃', '苗栗', '提供', '診斷']
# 189: ['雲嘉', '地區', '秋行軍蟲', '增加', '秋作']
# 1347: ['香蕉', '黑星病', '延後', '香蕉', '抽穗']
# 764: ['天氣', '漸涼', '雨水', '漸少', '印度棗']
# 228: ['水稻', '抽穗期', '二化螟', '成蛾', '盛期']
# 566: ['二期', '水稻', '生育', '初期', '縱捲葉蟲']
# 1025: ['斜紋夜蛾', '族群', '呼籲', '農友', '防治']
# 1033: ['本市', '斜紋夜蛾', '疫情', '升溫', '防治']
# 969: ['本局', '發佈', '全國', '滅鼠', '農地']
# 49: ['苗栗', '地區', '發布', '水稻', '白葉枯病']
# 809: ['縣內', '已有', '零星', '稻熱病', '發生']
# 821: ['番茄', '晚疫病', '疫情', '警報', '花蓮']
# 75: ['苗栗', '改場', '發布', '苗栗', '地區']
# 835: ['花蓮', '作物', '病蟲害', '疫情', '警報']
# 1392: ['日夜', '溫差', '變化', '高雄', '農業']
# 612: ['新聞稿', '水稻', '葉稻熱病', '防治', '南區']
# 1153: ['炭疽', '病菌', '殘存', '洋蔥', '採收']
# 1147: ['芒果', '花期', '慎防', '病蟲害', '高雄']
# 362: ['臺南', '改場', '芒果', '開花期', '防檢局']
# 1190: ['發佈', '年期', '區葉', '病害', '防治']
# 438: ['臺南', '改場', '籲請', '農友', '水稻']
# 1185: ['番茄潛旋蛾', '籲請', '農友', '確實', '防治']
# 411: ['清明', '時節', '氣候', '穩定', '稻熱病']
# 1191: ['宣導', '單位', '轄區', '蕉農', '香蕉']
# 1146: ['流來', '氣溫', '偏低', '高雄', '籲請']
# 1378: ['籲請', '農友', '木瓜', '黑腐病', '發生']
# 1350: ['香蕉葉', '病害', '影響', '抽穗', '飽熟']
# 997: ['梨木蝨', '危害', '農友', '防範', '梨木蝨']
# 767: ['入冬', '作物', '發生', '露菌病', '台南']
# 940: ['發佈', '水稻', '葉稻熱病', '警報', '本場']
# 1218: ['香蕉', '組織培養', '初春', '種植', '期間']
# 1230: ['蕉農', '香蕉葉', '黑星病', '防治', '工作']
# 968: ['花蓮', '發佈', '水稻', '穗稻熱病', '水稻']
# 571: ['水稻', '生育', '後期', '褐飛蝨', '防治']
# 549: ['氣候', '高溫', '水稻', '葉稻熱病', '防治']
# 561: ['池上', '稻熱病', '病徵', '台東', '改良場']
# 950: ['氣溫', '回升', '嚴防', '檬果', '小黃薊馬']
# 788: ['二期', '水稻', '臺南', '農業', '改良場']
# 1234: ['籲請', '單位', '轄區', '蕉農', '香蕉葉']
# 64: ['苗栗', '地區', '發布', '水稻', '葉稻熱病']
# 824: ['水稻', '穗稻熱病', '蔬菜', '瓜果', '病蟲害']
# 70: ['發布', '苗栗', '水稻', '葉稻熱病', '防治']
# 830: ['果實蠅', '為害', '早期', '防治效果', '花蓮縣']
# 1354: ['宣導', '轄區', '蕉農', '儘速', '白鹿']
# 1340: ['氣候', '香蕉葉', '病菌', '感染', '漫延']
# 603: ['瘤野螟', '稻縱捲葉蟲', '猖獗', '臺東區', '改場']
# 171: ['溫差', '稻株', '抵抗力', '稻熱病', '悄悄']
# 1142: ['時值', '紅豆', '栽培', '苗期', '病害']
# 1195: ['宣導', '蕉農', '做好', '抽穗', '蕉株']
# 373: ['芒果', '中果', '東方果實蠅', '炭疽病', '危害']
# 415: ['夜蛾', '警報', '白粉', '著來', '臺南']
# 1180: ['發佈', '年期', '區葉', '病害', '防治']
# 1194: ['發佈', '年期', '香蕉葉', '病害', '防治']
# 1157: ['洋蔥', '育苗', '病害', '防治', '高雄']
# 616: ['水稻', '分蘗', '盛期', '籲請', '農友']
# 1382: ['稻熱病', '蠢蠢欲動', '高雄', '農業', '改良場']
# 170: ['時值', '芒果', '花期', '籲請', '農友']
# 602: ['臺東縣', '太麻', '地區', '東方果實蠅', '猖獗']
# 1341: ['近期', '氣候', '香蕉葉', '病菌', '感染']
# 819: ['宜蘭縣', '中旬', '監測', '瓜實蠅', '斜紋夜蛾']
# 59: ['發布', '苗栗', '地區', '水稻', '葉稻熱病']
# 65: ['發布', '苗栗', '地區', '水稻', '螟蟲']
# 1369: ['農友', '稻熱病', '防治', '工作', '屏東市']
# 776: ['氣候', '多變', '慎防', '蔬菜', '露菌病']
# 986: ['苗栗', '農業', '改良場', '發佈', '水稻']
# 992: ['入侵', '果實蠅', '緊急', '撲滅', '模擬']
# 979: ['東區', '農業', '改良場', '發佈', '紋枯病']
# 789: ['颱風', '過後', '南區', '改場', '提醒']
# 951: ['蘇鐵', '鐵樹', '介殼蟲', '危害', '監測']
# 1037: ['近期', '東方果實蠅', '田間', '密度', '增加']
# 1023: ['嘉義市', '發現', '水稻', '稻熱病', '發生']
# 562: ['防治', '白葉枯病', '確保', '水稻', '產量']
# 576: ['防治', '穗稻熱病', '確保', '水稻', '產量']
# 1237: ['籲請', '蕉農', '繼續執行', '蕉株', '抽穗']
# 984: ['台中區', '農業', '改良場', '發佈', '水稻']
# 760: ['大雨', '南區', '改場', '茄科', '細菌性斑點病']
# 774: ['氣候', '多變', '溫差', '臺南', '籲請']
# 73: ['本場', '發布', '苗栗', '地區', '東方果實蠅']
# 67: ['發布', '苗栗', '地區', '東方果實蠅', '瓜實蠅']
# 199: ['荔枝', '小果', '臺中', '改場', '籲請']
# 1357: ['芒果', '盛花期', '小果', '農友', '防治']
# 9: ['水稻', '飛蝨類', '害蟲', '防治', '工作']
# 628: ['水稻', '分蘗期', '台南', '農友', '水稻']
# 1141: ['秋涼', '雨水', '減少', '高雄', '籲請']
# 1155: ['秋涼', '防範', '白粉病', '高雄', '改場']
# 370: ['水稻', '抽穗期', '正逢', '梅雨季', '農友']
# 365: ['臺南', '改場', '田間', '零星', '葉稻熱病']
# 403: ['花薊馬', '斜紋夜蛾', '蠢蠢欲動', '農應', '提前']
# 371: ['雨季', '芒果', '黑斑病', '易於', '傳播']
# 1381: ['芒果', '小黃薊馬', '族群', '密度', '持續']
# 1342: ['初春', '時期', '香蕉', '組織培養', '苗易']
# 66: ['發布', '苗栗', '地區', '斜紋夜盜蟲', '防治']
# 72: ['本場', '發布', '水稻', '葉稻熱病', '防治']
# 775: ['芒果', '小黃薊馬', '密度', '持續上升', '臺南']
# 1236: ['宣導', '蕉農', '做好', '香蕉', '黑星病']
# 946: ['桃園', '農業', '改良場', '發佈', '瘤野螟']
# 239: ['赤星病', '感染', '龍柏', '臺中', '農業']
# 588: ['氣候', '鋒面', '過後', '水稻', '葉稻熱病']
# 1011: ['果實蠅', '發生', '高峰期', '果農', '防治']
# 585: ['臺東縣', '水稻', '作請', '防治', '褐飛蝨']
# 591: ['天氣', '陰晴不定', '水稻', '紋枯病', '蠢蠢欲動']
# 1005: ['稻熱病', '季節', '防檢局', '籲請', '農友']
# 1039: ['臺中市', '斜紋夜蛾', '疫情', '升溫', '農友']
# 220: ['葡萄', '露菌病', '零星', '發生', '中場']
# 546: ['水稻', '陸續', '抽穗期', '適合', '穗稻熱病']
# 552: ['台東', '水稻', '紋枯病', '警報', '行政院']
# 1207: ['宣導', '蕉農', '持續', '做好', '香蕉']
# 963: ['台南', '發佈', '新聞稿', '夏季', '蔬菜']
# 977: ['中場', '發佈', '水稻', '紋枯病', '發生']
# 744: ['氣溫', '轉涼', '南區', '改場', '木瓜']
# 988: ['適合', '稻熱病', '發生', '持續', '監測']
# 1401: ['連續', '降雨', '籲請', '農友', '病蟲害']
# 181: ['怪獸', '蘇迪勒', '颱風', '肆虐', '籲請']
# 1373: ['美濃', '地區', '發生', '熱稻', '高屏地區']
# 57: ['苗栗', '地區', '發布', '水稻', '葉稻熱病']
# 817: ['近日', '監測', '縣內', '水稻田', '發現']
# 5: ['花蓮', '地區', '水稻', '褐飛蝨', '白背飛蝨']
# 630: ['時值', '稻作', '抽穗期', '台南', '農友']
# 142: ['近日', '氣候', '高雄', '改場', '籲請']
# 1165: ['春天', '氣候', '三變', '當心', '穗稻熱病']
# 383: ['水稻', '抽穗', '籲請', '農友', '田間']
# 1159: ['冷氣團', '高雄', '籲請', '農友', '防範']
# 369: ['嘉南', '地區', '水稻', '幼穗', '分化']
# 1170: ['發佈', '年度', '區葉', '病害', '防治']
# 382: ['水稻', '葉稻熱病', '疫情', '悄悄', '升溫']
# 619: ['檬果', '開花', '季節', '台南', '提醒']
# 81: ['梅雨', '鋒面', '農友', '芋頭', '病害']
# 95: ['發布', '年度', '水稻', '白葉枯病', '發生']
# 631: ['颱風', '過後', '台南', '改場', '籲請']
# 157: ['濕度', '疫病', '防範', '高雄', '改場']
# 816: ['近日', '宜蘭', '防疫', '監測', '縣內']
# 1366: ['稻熱病', '警訊', '屏東縣', '崁頂', '鹽埔']
# 194: ['赤星病', '感染', '龍柏', '臺中', '改場']
# 779: ['荔枝', '龍眼', '謝花', '小果', '臺南']
# 1206: ['宣導', '蕉農', '做好', '香蕉葉', '病害']
# 209: ['荔枝銹螨', '中部', '地區', '零星', '發生']
# 553: ['春夏', '交替', '之際', '細菌性斑點病', '報到']
# 235: ['水稻', '葉片', '葉稻熱病', '初期', '病斑']
# 590: ['水稻', '瘤野螟', '防治', '放鬆', '台東']
# 1010: ['提早', '入梅', '防範', '水稻', '稻熱病']
# 586: ['水稻', '瘤野螟', '水稻', '白葉枯病', '發生']
# 237: ['水稻', '抽穗期', '二化螟', '成蛾', '盛期']
# 223: ['水稻', '褐飛蝨', '白背飛蝨', '瘤野螟', '零星']
# 790: ['颱風', '過後', '台南', '改場', '水稻']
# 784: ['黃條葉蚤', '十字花科', '蔬菜', '作物', '危害']
# 753: ['豪雨', '過後', '柑橘類', '發生', '褐腐病']
# 747: ['柑橘類', '開花期', '農友', '蚜蟲', '潛葉蛾']
# 68: ['發布', '苗栗', '地區', '東方果實蠅', '害蟲']
# 1364: ['芒果', '葉蟬', '跳仔', '防治', '落花']
# 40: ['苗栗', '改場', '發佈', '水稻', '螟蟲']
# 800: ['流來', '臺南', '農業', '改良場', '籲請']
# 6: ['做好', '梨木蝨', '黑星病', '防治', '維護']
# 54: ['苗栗', '地區', '發布', '水稻', '飛蝨類']
# 141: ['近日', '降雨', '氣溫', '變化', '較大']
# 155: ['番茄病毒病', '時節', '高雄', '籲請', '農友']
# 633: ['冬季', '濕冷', '季節', '馬鈴薯', '番茄']
# 83: ['氣候', '高溫', '水稻', '葉稻熱病', '疫情']
# 97: ['發布', '水稻', '飛蝨類', '發生', '預報']
# 380: ['氣候變化', '籲請', '農友', '防範', '水稻']
# 1172: ['發佈', '年度', '區葉', '病害', '防治']
# 1166: ['落果', '清一清', '東方果實蠅', '把握', '防治']
# 343: ['夏季', '氣候', '連續', '降雨', '臺南']
# 431: ['先機', '臺南', '農業', '改良場', '籲請']
# 1199: ['宣導', '蕉農', '做好', '香蕉葉', '病害']
# 1198: ['天氣', '高溫', '香蕉', '黑星病', '葉斑病']
# 342: ['二期', '水稻', '瘤野螟', '時期', '臺南']
# 424: ['臺南', '改場', '籲請', '農友', '防治']
# 1167: ['氣溫', '臺南', '改場', '防治', '番茄']
# 381: ['柑橘類', '花期', '籲請', '農民', '小型']
# 1173: ['宣導', '社員', '香蕉', '果房', '花薊馬']
# 82: ['苗栗縣', '東方果實蠅', '密度', '增加', '防範']
# 154: ['天氣', '漸涼', '白粉病', '防範', '高雄']
# 140: ['雨季', '籲請', '農友', '防範', '荔枝']
# 55: ['苗栗', '地區', '發布', '水稻水象鼻蟲', '防治']
# 41: ['氣候', '高溫', '發生', '草莓苗期', '炭疽病']
# 197: ['葡萄', '露菌病', '零星', '發生', '中場']
# 829: ['花蓮', '作物', '病蟲害', '疫情', '警報']
# 1365: ['芒果', '開花期', '白粉病', '防治', '芒果']
# 183: ['降雨', '臺南', '農業', '改良場', '水稻']
# 746: ['杜絕', '洋香瓜', '病毒', '蔓延', '嘉南']
# 961: ['果實蠅', '發生', '高峰期', '果農', '防治']
# 1239: ['宣導', '蕉農', '抽穗期', '成熟斑', '防治']
# 785: ['大雨', '發生', '木瓜', '果實', '疫病']
# 791: ['南區', '改場', '籲請', '茄科', '細菌性斑點病']
# 949: ['桃園', '發佈', '轄區', '水稻', '葉稻熱病']
# 544: ['露菌病', '輕微', '發生', '臺中', '農業']
# 222: ['中部', '地區', '柑桔', '果實', '零星']
# 236: ['葡萄', '露菌病', '零星', '發生', '籲請']
# 587: ['氣候', '溫度', '農友', '防治', '水稻']
# 1007: ['乍暖還寒', '防檢局', '籲請', '農友', '防治']
# 597: ['臺東', '局部地區', '釋迦', '害蟲', '密度']
# 583: ['農友', '防治', '水稻', '紋枯病', '增進']
# 568: ['番茄', '晚疫病', '防治', '方法', '台東']
# 1229: ['近期', '調查', '香蕉', '組織培養', '種植']
# 795: ['嘉南', '地區', '褐飛蝨', '疫情', '臺南']
# 781: ['稻作', '抽穗期', '臺南', '改場', '農友']
# 805: ['發佈', '水稻水象鼻蟲', '防治', '警報', '苗栗']
# 51: ['苗栗', '地區', '發布', '水稻', '穗稻熱病']
# 3: ['夏季', '斜紋', '甜菜夜蛾', '發生', '盛期']
# 1375: ['時值', '芒果', '盛花期', '籲請', '農友']
# 1361: ['水稻', '穗稻熱病', '警訊', '氣候', '環境']
# 178: ['中度颱風', '蘇迪勒', '侵襲', '籲請', '農友']
# 86: ['水稻', '穗稻熱病', '發生', '桃園', '籲請']
# 144: ['高屏地區', '紅豆', '栽培', '高雄', '籲請']
# 622: ['檬果', '開花', '季節', '台南', '提醒']
# 636: ['柑桔窄胸天牛', '羽化', '農友', '柑桔窄胸天牛', '防治']
# 150: ['泰利', '颱風', '來勢洶洶', '高雄', '籲請']
# 391: ['籲請', '農友', '水稻', '紋枯病', '白葉枯病']
# 434: ['稻熱病', '發生', '籲請', '農友', '防治']
# 421: ['連續', '降雨', '臺南', '改場', '提醒']
# 1176: ['宣導', '社員', '香蕉', '果房', '花薊馬']
# 151: ['大雨', '過後', '高雄', '籲請', '紅豆']
# 93: ['發布', '水稻', '瘤野螟', '縱捲葉蟲', '發生']
# 179: ['蘇迪勒', '強風', '豪雨', '籲請', '農友']
# 186: ['荔枝椿象', '越冬', '籲請', '農友', '荔枝椿象']
# 838: ['花蓮', '作物', '病蟲害', '疫情', '警報']
# 78: ['本場', '發布', '苗栗', '地區', '東方果實蠅']
# 810: ['日本', '監測', '縣內', '水稻田', '發現']
# 44: ['苗栗', '地區', '發布', '水稻', '螟蟲']
# 780: ['柑橘窄胸天牛', '羽化', '臺南', '改場', '防治']
# 1228: ['蕉株', '抽穗', '時期', '籲請', '蕉農']
# 582: ['東方果實蠅', '密度', '臺東', '籲請', '農民']
# 1016: ['拉克', '颱風', '農作物', '措施', '拉克']
# 594: ['水稻', '抽穗期', '氣候', '陰晴不定', '溫溼度']
# 1000: ['新聞稿', '稻熱病', '季節', '防檢局', '籲請']
# 219: ['臺中', '改場', '中部', '地區', '氣溫']
# 225: ['氣溫', '回升', '黑角舞蛾', '蠢動', '籲請']
# 782: ['東方果實蠅', '密度', '持續上升', '臺南', '農業']
# 741: ['南區', '改場', '防治', '斜紋夜盜蟲', '確保']
# 755: ['台南', '瓜農', '病媒', '銀葉粉蝨', '防治']
# 46: ['發布', '水稻', '白葉枯病', '飛蝨類', '蟲害']
# 806: ['水稻水象鼻蟲', '螟蟲', '二化螟', '三化螟', '已於']
# 184: ['颱風', '過後', '心慌慌', '田間', '巡視']
# 609: ['發佈', '新聞稿', '提醒', '農民', '防治']
# 85: ['桃園', '發布', '水稻', '葉稻熱病', '疫情']
# 635: ['冬季', '濕冷', '季節', '花卉', '灰黴病']
# 147: ['近日', '氣候', '陰晴不定', '高雄', '籲請']
# 1148: ['氣溫', '回暖', '溫差', '稻熱病', '防治']
# 392: ['水稻', '抽穗期', '臺南', '改場', '防治']
# 437: ['近期', '降雨', '頻繁', '臺南', '改場']
# 351: ['柑橘類', '盛花期', '臺南', '籲請', '農友']
# 344: ['早晚', '溫差', '大濕度', '臺南', '籲請']
# 436: ['荔枝椿象', '若蟲', '發生', '臺南', '農業']
# 387: ['文旦柚', '果實', '漸入', '成熟', '階段']
# 1161: ['降低', '荔枝椿象', '密度', '防範', '荔枝']
# 620: ['紫斑病', '薊馬', '危害', '日益嚴重', '農民']
# 152: ['豪雨', '過後', '高雄', '籲請', '農友']
# 185: ['斜紋夜蛾', '密度', '增加', '農友', '防治']
# 191: ['夏季', '炎熱', '蟲害', '密度', '提醒']
# 807: ['二期', '水稻', '生育', '初期', '縱捲葉蟲']
# 1: ['梅雨季', '來臨', '文旦', '黑點病', '發生']
# 998: ['防範', '梨木蝨', '危害', '農友', '配合']
# 740: ['稻縱捲葉蟲', '發生', '台南', '改場', '提醒']
# 797: ['氣候', '多變', '日夜', '溫差', '大極']
# 1217: ['蕉株', '抽穗', '時期', '蕉農', '做好']
# 783: ['柑橘園', '密度', '臺南', '改場', '籲請']
# 973: ['台中區', '農業', '改良場', '發布', '西瓜']
# 967: ['台南', '發佈', '果實蠅', '發生', '高峰期']
# 230: ['水稻', '白葉枯病', '飛蝨類', '瘤野螟', '成蛾']
# 556: ['水稻', '插秧', '季節', '請留', '水稻水象鼻蟲']
# 542: ['氣候', '持續', '溼熱', '適合', '水稻']
# 595: ['鹿野', '局部地區', '水稻', '胡麻葉枯病', '發生']
# 1015: ['稻熱病', '蠢蠢欲動', '防檢局', '籲請', '農友']
# 1066: ['葡萄', '露菌病', '發生', '蔓延', '臺中']
# 243: ['水稻', '抽穗期', '二化螟', '成蛾', '盛期']
# 727: ['芒果', '陸續', '開花期', '南區', '農業']
# 733: ['柑桔窄胸天牛', '羽化', '台南', '改場', '防治']
# 690: ['台南', '地區', '洋香瓜', '種植', '季節']
# 1304: ['梅雨季', '高溫', '潮濕', '防範', '香蕉葉']
# 1310: ['蕉果', '水銹斑', '影響', '香蕉', '外觀']
# 684: ['柑桔窄胸天牛', '羽化', '農友', '防治', '柑桔窄胸天牛']
# 34: ['苗栗', '發佈', '水稻', '螟蟲', '瘤野螟']
# 874: ['花蓮', '宜蘭', '地區', '作物', '病蟲害']
# 653: ['時值', '檬果', '開花期', '南區', '農業']
# 121: ['高雄', '近日', '連續', '午後', '降雨']
# 337: ['蓮花', '小黃薊馬', '密度', '臺南', '農業']
# 478: ['水稻', '白葉枯病', '胡麻葉枯病', '警報', '警報']
# 493: ['苗栗', '改場', '發布', '水稻', '葉稻熱病']
# 108: ['氣溫', '高升', '高屏地區', '瓜實蠅', '族群']
# 646: ['豪雨', '雷雨', '台南', '改場', '籲請']
# 652: ['龍眼', '褐根病', '蔓延', '台南', '改場']
# 21: ['中國', '梨木蝨', '密度', '攀升', '防治']
# 875: ['漸入', '颱風', '季節', '留意', '颱風']
# 1339: ['籲請', '蕉農', '香蕉葉', '病害', '防治']
# 35: ['苗栗', '改場', '發佈', '斜紋夜蛾', '疫情']
# 1311: ['提高', '成活率', '維護', '香蕉', '蕉株']
# 1305: ['雨季', '期間', '香蕉', '黑星病', '葉斑病']
# 691: ['颱風', '過後', '連續', '下雨', '南區']
# 732: ['芒果園', '小黃薊馬', '密度', '南區', '農業']
# 726: ['銹病', '紫斑病', '好發', '氣候', '環境']
# 1265: ['香蕉', '嵌紋病', '媒介', '蚜蟲', '繁殖']
# 1271: ['香蕉', '籲請', '蕉農', '務必', '做好']
# 530: ['水稻', '瘤野螟', '成蛾', '陸續', '羽化']
# 524: ['為害', '果樹', '黑角舞蛾', '幼蟲', '中部']
# 242: ['近期', '氣候', '劇烈', '變化', '間歇性']
# 295: ['番荔枝', '萌芽期', '籲請', '釋迦', '農友']
# 1067: ['氣候變化', '臺南', '農業', '改良場', '稻熱病']
# 1073: ['夜盜蟲', '密度', '持續', '升高', '臺南']
# 297: ['梅雨', '鋒面', '影響', '臺灣', '農友']
# 283: ['蘇力', '颱風', '來勢洶洶', '臺東', '籲請']
# 532: ['赤星病', '發生', '台中區', '改場', '籲請']
# 268: ['天氣', '穩定', '降雨', '柑桔', '果農']
# 1267: ['香蕉', '籲請', '蕉農', '蕉株', '抽穗']
# 730: ['芒果', '開花', '盛期', '台南', '改場']
# 724: ['田園', '管理', '起工', '柑橘類', '採收']
# 1298: ['香蕉', '近日', '溫差', '露水', '香蕉']
# 693: ['秋天', '咖啡', '銹病', '季節', '南區']
# 37: ['荔枝椿象', '出沒', '危害', '防治', '措施']
# 644: ['大雨', '防治', '楊桃', '細菌性斑點病', '大雨']
# 678: ['小黃薊馬', '密度', '農友', '防治', '確保']
# 1111: ['葡萄', '露菌病', '發生', '中場', '籲請']
# 446: ['水稻', '流行病', '稻熱病', '季節', '農友']
# 453: ['稻熱病', '高峰期', '花蓮', '農業', '改良場']
# 321: ['芒果', '開花期', '臺南', '改場', '農友']
# 484: ['發佈', '水稻', '二化螟', '警報', '病蟲害']
# 679: ['時值', '園藝作物', '生長', '盛期', '南區']
# 645: ['稻縱捲葉蟲', '發生', '台南', '改場', '提醒']
# 876: ['十字花科', '蔬菜', '殺手', '黃條葉蚤', '氣候']
# 862: ['少見', '番茄', '菌核病', '農友', '即時']
# 692: ['連續', '大雨', '南區', '改場', '提醒']
# 725: ['天氣', '濕冷', '馬鈴薯', '番茄', '晚疫病']
# 916: ['發佈', '水稻', '紋枯病', '白葉枯病', '疫情']
# 527: ['水稻', '陸續', '抽穗期', '氣候', '轉為']
# 282: ['番荔枝', '害蟲', '密度', '升高', '臺東']
# 296: ['連續', '籲請', '農友', '防治', '稻熱病']
# 292: ['水稻', '瘤野螟', '縱捲葉蟲', '發生', '農友']
# 1074: ['氣候', '溫暖', '穩定', '臺南', '農業']
# 286: ['中秋佳節', '颱風', '影響', '臺東', '籲請']
# 279: ['天氣', '忽冷忽熱', '臺東', '籲請', '稻農']
# 906: ['發佈', '水稻水象鼻蟲', '疫情', '警報', '病蟲害']
# 1276: ['香蕉', '籲請', '轄區', '蕉農', '繼續加強']
# 709: ['柑桔窄胸天牛', '羽化', '台南', '改場', '防治']
# 1289: ['香蕉', '水銹斑', '影響', '香蕉', '外觀']
# 26: ['發佈', '荔枝椿象', '防治', '警報', '轉知']
# 866: ['果實蠅', '防治', '確保', '水果', '產量']
# 32: ['改場', '草莓苗期', '炭疽病', '疫情', '近日']
# 872: ['花蓮', '宜蘭', '地區', '作物', '病蟲害']
# 682: ['梅雨季節', '即將來臨', '台南', '籲請', '防治']
# 1302: ['香蕉', '近日', '晴雨', '適合', '香蕉']
# 899: ['屏東縣', '枋寮', '上旬', '監測', '果實蠅']
# 133: ['水稻', '葉稻熱病', '蠢蠢欲動', '籲請', '農友']
# 1128: ['中部', '地區', '一期稻作', '水稻', '穗稻熱病']
# 480: ['苗栗', '地區', '水稻', '栽培', '插秧']
# 1114: ['水稻', '瘤野螟', '成蛾', '陸續', '羽化']
# 319: ['水稻', '開花', '農友', '防範', '穗稻熱病']
# 325: ['芒果', '小黃薊馬', '密度', '持續上升', '臺南']
# 457: ['颱風', '過後', '水稻', '紋枯病', '白葉枯病']
# 456: ['花蓮', '地區', '水稻', '瘤野螟', '發生']
# 330: ['荔枝', '龍眼', '小果', '臺南', '改場']
# 442: ['花蓮', '宜蘭', '地區', '作物', '病蟲害']
# 654: ['紫斑病', '薊馬', '危害', '日益嚴重', '台南']
# 898: ['月份', '果實蠅', '密度', '持續上升', '農友']
# 126: ['屏東縣', '枋山', '地區', '芒果', '黑斑病']
# 27: ['發佈', '水稻', '白葉枯病', '飛蝨類', '蟲害']
# 1263: ['籲請', '蕉農', '防範', '抽穗期', '蕉株']
# 913: ['水稻', '秧苗', '健康', '管理', '北部']
# 522: ['早晚', '露水', '適合', '葡萄', '露菌病']
# 1075: ['稻熱病', '農友', '防範', '臺東區', '改場']
# 1049: ['發佈', '水稻', '螟蟲', '二化螟', '三化螟']
# 285: ['臺東', '調查', '水稻', '發現', '瘤野螟']
# 1088: ['一期稻作', '紋枯病', '警報', '一期稻作', '水稻']
# 508: ['苗栗縣', '二期', '發現', '瘤野螟', '危害']
# 905: ['發佈', '水稻', '螟蟲', '縱捲葉蟲', '警報']
# 1249: ['籲請', '蕉農', '香蕉葉', '黑星病', '防治']
# 911: ['發佈', '水稻', '白葉枯病', '疫情', '警報']
# 1261: ['宣導', '單位', '轄區', '香蕉葉', '病害']
# 722: ['大蒜', '薊馬', '密度', '漸增', '南區']
# 1329: ['防堵', '秋行軍蟲', '呼籲', '農民', '田間']
# 25: ['發佈', '草莓苗期', '炭疽病', '防治', '警報']
# 865: ['水稻', '分蘗', '盛期', '引發', '紋枯病']
# 695: ['颱風', '過後', '水稻', '褐飛蝨', '密度']
# 1301: ['香蕉', '近日', '低溫', '細雨', '香蕉葉']
# 1315: ['蕉株', '抽穗', '期間', '籲請', '蕉農']
# 656: ['一期稻作', '分蘗期', '台南', '籲請', '農友']
# 642: ['蓮花', '小黃薊馬', '族群', '增加', '台南']
# 1103: ['一期稻作', '穗稻熱病', '發生', '警報', '本場']
# 326: ['水稻', '葉稻熱病', '臺南', '改場', '籲請']
# 441: ['荔枝', '龍眼', '小果', '防治', '荔枝細蛾']
# 333: ['梅雨季節', '臺南', '提醒', '防治', '木瓜']
# 1116: ['連續', '降雨', '葡萄', '露菌病', '提早']
# 482: ['水稻水象鼻蟲', '發生', '農民', '防治', '糧食作物']
# 131: ['近日', '天氣', '轉濕', '農友', '防範']
# 119: ['雨季', '即將來臨', '荔枝', '病害', '蠢蠢欲動']
# 858: ['水稻水象鼻蟲', '蠢蠢欲動', '防治', '行政院', '農業']
# 680: ['一期稻作', '抽穗期', '農友', '穗稻熱病', '紋枯病']
# 1300: ['香蕉', '抽穗期', '香蕉', '籲請', '農友']
# 694: ['連續', '陰雨', '台南', '改場', '提醒']
# 864: ['青蔥', '管仔蟲', '甜菜夜蛾', '防治', '青蔥']
# 870: ['推動', '果實蠅', '防治', '雄蟲', '自投羅網']
# 1274: ['香蕉', '籲請', '轄區', '蕉農', '香蕉葉']
# 904: ['發佈', '蓮花', '小黃薊馬', '蟲害', '發生']
# 521: ['水稻', '瘤野螟', '成蛾', '陸續', '羽化']
# 1076: ['氣候', '條件', '適合', '水稻', '葉稻熱病']
